# %%
import pytest
import simuOpt
simuOpt.setOptions(alleleType='short', quiet=True)
import simuPOP as sim
import pandas as pd
from saegus import breed, operators, simulate, analyze, parse, parameters
import shelve
import numpy as np
import random
np.set_printoptions(suppress=True, precision=3)

# %%
trait_parameters = shelve.open('magic_1478_trait_parameters')

# %%
list(trait_parameters.keys())
# Out:
# ['allele_effect_parameters', 'number_of_qtl']

# %%
simulation_parameters = shelve.open('magic_1478_simulation_parameters')

# %%
list(simulation_parameters.keys())
# Out:
# ['alleles',
#  'founders',
#  'operating_population_size',
#  'prefounder_file_name',
#  'recombination_rates',
#  'number_of_replicates']

# %%
magic1478 = sim.loadPopulation('magic_1478.pop')

# %%
magic1478.dvars()
# Out:
# {'gen': 3, 'rep': 0}

# %%
magic_1478_rmd0 = sim.loadPopulation('magic_random_0.pop')

# %%
simulation_parameters = shelve.open('magic_1478_simulation_parameters')

# %%
simulation_parameters['alleles']
# Out:
# {0: [1, 2],
#  1: [1, 3],
#  2: [3, 1],
#  3: [0, 2],
#  4: [2, 0],
#  5: [0, 2],
#  6: [0, 2],
#  7: [3, 1],
#  8: [0, 2],
#  9: [1, 3],
#  10: [1, 3],
#  11: [1, 3],
#  12: [3, 1],
#  13: [2, 0],
#  14: [3, 0],
#  15: [3, 1],
#  16: [2, 3],
#  17: [2, 3],
#  18: [2, 0],
#  19: [5, 4],
#  20: [3, 0],
#  21: [2, 1],
#  22: [2, 3],
#  23: [5, 4],
#  24: [1, 3],
#  25: [2, 0],
#  26: [3, 0],
#  27: [0, 1],
#  28: [2, 1],
#  29: [2, 0],
#  30: [2, 0],
#  31: [0, 1],
#  32: [3, 1],
#  33: [0, 3],
#  34: [1, 3],
#  35: [2, 3],
#  36: [1, 3],
#  37: [3, 1],
#  38: [5, 4],
#  39: [0, 2],
#  40: [1, 3],
#  41: [2, 0],
#  42: [2, 1],
#  43: [3, 0],
#  44: [0, 2],
#  45: [2, 0],
#  46: [3, 1],
#  47: [3, 1],
#  48: [2, 0],
#  49: [2, 0],
#  50: [1, 2],
#  51: [3, 1],
#  52: [1, 3],
#  53: [0, 1],
#  54: [1, 0],
#  55: [2, 0],
#  56: [1, 3],
#  57: [1, 0],
#  58: [1, 3],
#  59: [1, 3],
#  60: [1, 3],
#  61: [2, 3],
#  62: [2, 0],
#  63: [2, 0],
#  64: [0, 3],
#  65: [2, 0],
#  66: [2, 3],
# ...
