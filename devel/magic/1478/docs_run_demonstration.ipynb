# %%
import simuOpt
simuOpt.setOptions(alleleType='short', optimized=True, numThreads=4, quiet=True)
import simuPOP as sim
import pandas as pd
from saegus import breed, operators, simulate, analyze, parse, parameters
import shelve
import numpy as np
import random
import collections as col
np.set_printoptions(suppress=True, precision=3)

# %%
run_id='demonstration'

# %%
number_of_replicates = 5

# %%
sample_sizes=[500, 600, 700, 800, 900, 1000]

# %%
number_of_qtl = 10

# %%
prefounders = sim.loadPopulation('prefounders1478.pop')
multi_prefounders = sim.Simulator(prefounders, number_of_replicates, stealPops=False)
founders = [[2, 26], [3, 25], [4, 24], [5, 23]]
os_per_pair = 500
magic = breed.MAGIC(multi_prefounders, founders, [0.01]*1478)
sim.tagID(prefounders, reset=27)
magic.generate_f_one(founders, os_per_pair)
mrc = breed.MultiRandomCross(multi_prefounders, 4, 500)
mother_choices, father_choices = mrc.determine_random_cross()
multi_snd_ord_chooser = breed.MultiSecondOrderPairIDChooser(mother_choices, father_choices)
multi_prefounders.evolve(
    matingScheme=sim.HomoMating(
        sim.PyParentsChooser(multi_snd_ord_chooser.snd_ord_id_pairs),
        sim.OffspringGenerator(ops=[
            sim.IdTagger(),
            sim.PedigreeTagger(),
            sim.Recombinator(rates=0.01)
        ],
            numOffspring=1),
        subPopSize=[2000],
    ),
    gen=1,
)
final_mrc = breed.MultiRandomCross(multi_prefounders, 2, 1000)
final_mothers, final_fathers = final_mrc.determine_random_cross()
final_multi_snd_ord_chooser = breed.MultiSecondOrderPairIDChooser(final_mothers, final_fathers)
multi_prefounders.evolve(
    matingScheme=sim.HomoMating(
        sim.PyParentsChooser(final_multi_snd_ord_chooser.snd_ord_id_pairs),
        sim.OffspringGenerator(ops=[
            sim.IdTagger(),
            sim.PedigreeTagger(),
            sim.Recombinator(rates=0.01)
        ],
            numOffspring=1),
        subPopSize=[2000],
    ),
    gen=1,
)
mater = breed.MAGIC(multi_prefounders, founders, [0.01]*1478)
mater.random_mating(3, 2000)
# Out:
# Initiating random mating for 3 generations.

# %%
demonstration = analyze.Study(run_id)

# %%
sample_library = demonstration.collect_samples(multi_prefounders, sample_sizes)

# %%
sample_library
# Out:
# {0: [<simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>],
#  1: [<simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>],
#  2: [<simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>],
#  3: [<simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>],
#  4: [<simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>,
#   <simuPOP.Population>]}

# %%
pwd
# Out:
# 'C:\\Users\\DoubleDanks\\BISB\\wisser\\code\\rjwlab-scripts\\saegus_project\\devel\\magic\\1478'

# %%
alleles = np.array(pd.read_hdf('parameters\\alleles_at_1478_loci.hdf'))

# %%
for rep_id, sample_list in sample_library.items():
    for sample in sample_list:
        sim.stat(sample, alleleFreq=sim.ALL_AVAIL)

# %%
demonstration.store_allele_frequencies(sample_library, alleles)
# Out:
# C:\Anaconda3\lib\site-packages\tables\path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '500'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# C:\Anaconda3\lib\site-packages\tables\path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '600'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# C:\Anaconda3\lib\site-packages\tables\path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '700'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# C:\Anaconda3\lib\site-packages\tables\path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '800'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# C:\Anaconda3\lib\site-packages\tables\path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '900'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# C:\Anaconda3\lib\site-packages\tables\path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '1000'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)

# %%
allele_frequencies = pd.HDFStore('demonstration_allele_frequency_storage.h5')

# %%
sample_sizes
# Out:
# [500, 600, 700, 800, 900, 1000]

# %%
allele_frequencies.close()

# %%
sets_of_segregating_loci = demonstration.seg_loci_among_samples(sample_library)

# %%
sets_of_segregating_loci.values()
# Out:
# dict_values([30])

# %%
concordant_segregating_loci = list(sets_of_segregating_loci.keys())[0]

# %%
concordant_segregating_loci[::100]
# Out:
# (1, 159, 329, 483, 632, 785, 950, 1095, 1254, 1413)

# %%
qtl = tuple(sorted(random.sample(concordant_segregating_loci, number_of_qtl)))

# %%
qtl
# Out:
# (56, 255, 465, 472, 616, 1030, 1141, 1247, 1327, 1468)

# %%
add_trait = parameters.Trait()
allele_effects = add_trait.assign_allele_effects(alleles, qtl, random.expovariate, 1, multiplicity=1)

# %%
allele_effects
# Out:
# {56: {1: 2.2812691945674968, 3: 0.48357569403108913},
#  255: {1: 0.6747500901207086, 3: 1.5632913345055426},
#  465: {1: 0.6888397005445828, 3: 1.5293488062276326},
#  472: {0: 0.08405376413465437, 1: 1.211195259597092},
#  616: {1: 0.19086429218337728, 3: 0.2893219884051875},
#  1030: {1: 0.2603456951411934, 3: 0.49506270330959246},
#  1141: {1: 1.1232078799522691, 2: 1.063124727790315},
#  1247: {1: 3.8635674058046083, 3: 0.05602116696649215},
#  1327: {0: 3.5076628660065423, 2: 0.7912709232384485},
#  1468: {0: 0.7695915531897579, 2: 1.209493868151905}}

# %%
allele_effects_store = shelve.open('allele_effects_storage')
allele_effects_store['demonstration'] = allele_effects
allele_effects_store.close()

# %%
with shelve.open('demonstration_loci_conversions') as lconvert:
    nuloci_conversions = lconvert['saegus_to_tassel']

# %%
loci_conversions = shelve.open('demonstration_loci_conversions')

# %%
allele_effects_storage = shelve.open('allele_effects_storage')

# %%
allele_effects_storage['demonstration']
# Out:
# {56: {1: 2.2812691945674968, 3: 0.48357569403108913},
#  255: {1: 0.6747500901207086, 3: 1.5632913345055426},
#  465: {1: 0.6888397005445828, 3: 1.5293488062276326},
#  472: {0: 0.08405376413465437, 1: 1.211195259597092},
#  616: {1: 0.19086429218337728, 3: 0.2893219884051875},
#  1030: {1: 0.2603456951411934, 3: 0.49506270330959246},
#  1141: {1: 1.1232078799522691, 2: 1.063124727790315},
#  1247: {1: 3.8635674058046083, 3: 0.05602116696649215},
#  1327: {0: 3.5076628660065423, 2: 0.7912709232384485},
#  1468: {0: 0.7695915531897579, 2: 1.209493868151905}}

# %%
allele_effects = allele_effects_storage['demonstration']

# %%
allele_effects_storage.close()

# %%
loci_conversions.close()

# %%
allele_effects
# Out:
# {56: {1: 2.2812691945674968, 3: 0.48357569403108913},
#  255: {1: 0.6747500901207086, 3: 1.5632913345055426},
#  465: {1: 0.6888397005445828, 3: 1.5293488062276326},
#  472: {0: 0.08405376413465437, 1: 1.211195259597092},
#  616: {1: 0.19086429218337728, 3: 0.2893219884051875},
#  1030: {1: 0.2603456951411934, 3: 0.49506270330959246},
#  1141: {1: 1.1232078799522691, 2: 1.063124727790315},
#  1247: {1: 3.8635674058046083, 3: 0.05602116696649215},
#  1327: {0: 3.5076628660065423, 2: 0.7912709232384485},
#  1468: {0: 0.7695915531897579, 2: 1.209493868151905}}

# %%
demon_allele_effects

# %%
def record_loci_conversions(loci_conversion_file_name, concordant_segregating_loci):
    """
    At present I cannot get TASSEL to run with using consistent locus names.
    The loci in TASSEL are relabeled in terms of index regardless of their
    absolute position in the saegus data.
    
    This function records a map to make it possible to go back and forth
    between TASSEL labeled loci and saegus labeled loci.
    """
    with shelve.open(loci_conversion_file_name) as loci_conversion_file:
        loci_conversion_file['saegus_to_tassel'] = {locus: idx for locus, idx in enumerate(concordant_segregating_loci)}
        loci_conversion_file['tassel_to_saegus'] = dict(zip(loci_conversion_file['saegus_to_tassel'].values(), 
                                                            loci_conversion_file['saegus_to_tassel'].keys()))

# %%
record_loci_conversions('demo_example_loc_verts', concordant_segregating_loci)

# %%
reop = shelve.open('demo_example_loc_verts')

# %%
sae_to_tas = {locus: idx for locus,idx in enumerate(concordant_segregating_loci)}

# %%
sae_to_tas

# %%
inverted_sae_to_tas = dict(zip(sae_to_tas.values(), sae_to_tas.keys()))

# %%
inverted_sae_to_tas

# %%
sae_to_tas

# %%
loci_conversions = shelve.open('demonstration_loci_conversions')
saegus_to_tassel_loci = {}
tassel_to_saegus_loci = {}
for idx, locus in enumerate(concordant_segregating_loci):
    saegus_to_tassel_loci[locus] = idx
    tassel_to_saegus_loci[idx] = locus
#loci_conversions['saegus_to_tassel'] = saegus_to_tassel_loci
#loci_conversions['tassel_to_saegus'] = tassel_to_saegus_loci
#loci_conversions.close()

# %%
saegus_to_tassel_loci
# Out:
# {1: 0,
#  2: 1,
#  3: 2,
#  4: 3,
#  5: 4,
#  6: 5,
#  8: 6,
#  10: 7,
#  12: 8,
#  13: 9,
#  14: 10,
#  15: 11,
#  16: 12,
#  20: 13,
#  21: 14,
#  23: 15,
#  24: 16,
#  25: 17,
#  26: 18,
#  27: 19,
#  29: 20,
#  30: 21,
#  31: 22,
#  32: 23,
#  34: 24,
#  36: 25,
#  37: 26,
#  38: 27,
#  39: 28,
#  40: 29,
#  42: 30,
#  45: 31,
#  46: 32,
#  50: 33,
#  52: 34,
#  53: 35,
#  54: 36,
#  56: 37,
#  59: 38,
#  61: 39,
#  62: 40,
#  63: 41,
#  66: 42,
#  67: 43,
#  68: 44,
#  70: 45,
#  71: 46,
#  74: 47,
#  76: 48,
#  77: 49,
#  79: 50,
#  80: 51,
#  82: 52,
#  86: 53,
#  88: 54,
#  90: 55,
#  91: 56,
#  95: 57,
#  96: 58,
#  97: 59,
#  98: 60,
#  99: 61,
#  100: 62,
#  101: 63,
#  103: 64,
#  104: 65,
#  106: 66,
#  107: 67,
#  108: 68,
#  109: 69,
#  114: 70,
#  115: 71,
#  116: 72,
#  119: 73,
#  120: 74,
#  121: 75,
#  122: 76,
#  123: 77,
#  124: 78,
#  126: 79,
#  127: 80,
#  128: 81,
#  129: 82,
#  130: 83,
#  132: 84,
#  134: 85,
#  136: 86,
#  138: 87,
#  139: 88,
#  140: 89,
#  141: 90,
#  144: 91,
#  145: 92,
#  146: 93,
#  147: 94,
#  149: 95,
#  152: 96,
#  153: 97,
#  155: 98,
#  158: 99,
#  159: 100,
#  163: 101,
#  165: 102,
#  168: 103,
#  170: 104,
#  171: 105,
#  172: 106,
#  173: 107,
#  174: 108,
#  175: 109,
#  177: 110,
#  181: 111,
#  182: 112,
#  185: 113,
#  186: 114,
#  190: 115,
#  191: 116,
#  192: 117,
#  193: 118,
#  196: 119,
#  198: 120,
#  202: 121,
#  208: 122,
#  209: 123,
#  211: 124,
#  212: 125,
#  214: 126,
#  215: 127,
#  218: 128,
#  219: 129,
#  220: 130,
#  221: 131,
#  223: 132,
#  224: 133,
#  225: 134,
#  227: 135,
#  229: 136,
#  232: 137,
#  235: 138,
#  240: 139,
#  241: 140,
#  246: 141,
#  247: 142,
#  249: 143,
#  250: 144,
#  252: 145,
#  253: 146,
#  254: 147,
#  255: 148,
#  256: 149,
#  257: 150,
#  258: 151,
#  259: 152,
#  261: 153,
#  262: 154,
#  263: 155,
#  264: 156,
#  265: 157,
#  266: 158,
#  268: 159,
#  270: 160,
#  272: 161,
#  274: 162,
#  275: 163,
#  277: 164,
#  278: 165,
#  279: 166,
#  280: 167,
#  282: 168,
#  283: 169,
#  284: 170,
#  285: 171,
#  288: 172,
#  291: 173,
#  292: 174,
#  293: 175,
#  294: 176,
#  297: 177,
#  299: 178,
#  300: 179,
#  301: 180,
#  302: 181,
#  303: 182,
#  304: 183,
#  305: 184,
#  307: 185,
#  308: 186,
#  310: 187,
#  311: 188,
#  312: 189,
#  313: 190,
#  314: 191,
#  315: 192,
#  316: 193,
#  317: 194,
#  318: 195,
#  319: 196,
#  321: 197,
#  327: 198,
#  328: 199,
#  329: 200,
#  331: 201,
#  333: 202,
#  334: 203,
#  335: 204,
#  336: 205,
#  338: 206,
#  339: 207,
#  341: 208,
#  342: 209,
#  344: 210,
#  345: 211,
#  346: 212,
#  348: 213,
#  349: 214,
#  350: 215,
#  352: 216,
#  353: 217,
#  354: 218,
#  355: 219,
#  356: 220,
#  359: 221,
#  361: 222,
#  362: 223,
#  363: 224,
#  366: 225,
#  367: 226,
#  375: 227,
#  378: 228,
#  379: 229,
#  380: 230,
#  381: 231,
#  382: 232,
#  383: 233,
#  384: 234,
#  387: 235,
#  388: 236,
#  389: 237,
#  390: 238,
#  392: 239,
#  393: 240,
#  394: 241,
#  395: 242,
#  398: 243,
#  399: 244,
#  400: 245,
#  401: 246,
#  402: 247,
#  404: 248,
#  408: 249,
#  410: 250,
#  411: 251,
#  412: 252,
#  413: 253,
#  418: 254,
#  420: 255,
#  421: 256,
#  423: 257,
#  426: 258,
#  428: 259,
#  429: 260,
#  430: 261,
#  431: 262,
#  432: 263,
#  433: 264,
#  434: 265,
#  435: 266,
#  436: 267,
#  437: 268,
#  438: 269,
#  440: 270,
#  441: 271,
#  442: 272,
#  443: 273,
#  445: 274,
#  447: 275,
#  448: 276,
#  449: 277,
#  450: 278,
#  451: 279,
#  452: 280,
#  453: 281,
#  454: 282,
#  456: 283,
#  460: 284,
#  461: 285,
#  462: 286,
#  464: 287,
#  465: 288,
#  468: 289,
#  469: 290,
#  471: 291,
#  472: 292,
#  474: 293,
#  475: 294,
#  477: 295,
#  478: 296,
#  479: 297,
#  480: 298,
#  481: 299,
#  483: 300,
#  484: 301,
#  485: 302,
#  487: 303,
#  488: 304,
#  489: 305,
#  491: 306,
#  492: 307,
#  494: 308,
#  495: 309,
#  497: 310,
#  498: 311,
#  499: 312,
#  500: 313,
#  501: 314,
#  502: 315,
#  503: 316,
#  504: 317,
#  505: 318,
#  506: 319,
#  507: 320,
#  508: 321,
#  510: 322,
#  512: 323,
#  513: 324,
#  515: 325,
#  517: 326,
#  518: 327,
#  520: 328,
#  521: 329,
#  524: 330,
#  525: 331,
#  526: 332,
#  527: 333,
#  529: 334,
#  530: 335,
#  532: 336,
#  536: 337,
#  539: 338,
#  540: 339,
#  543: 340,
#  544: 341,
#  547: 342,
#  548: 343,
#  549: 344,
#  550: 345,
#  551: 346,
#  552: 347,
#  553: 348,
#  556: 349,
#  557: 350,
#  558: 351,
#  559: 352,
#  560: 353,
#  564: 354,
#  565: 355,
#  567: 356,
#  568: 357,
#  570: 358,
#  571: 359,
#  573: 360,
#  576: 361,
#  577: 362,
#  578: 363,
#  579: 364,
#  582: 365,
#  583: 366,
#  584: 367,
#  585: 368,
#  586: 369,
#  587: 370,
#  589: 371,
#  591: 372,
#  592: 373,
#  593: 374,
#  595: 375,
#  597: 376,
#  598: 377,
#  599: 378,
#  600: 379,
#  602: 380,
#  604: 381,
#  605: 382,
#  606: 383,
#  608: 384,
#  609: 385,
#  610: 386,
#  611: 387,
#  614: 388,
#  615: 389,
#  616: 390,
#  617: 391,
#  619: 392,
#  621: 393,
#  624: 394,
#  625: 395,
#  627: 396,
#  628: 397,
#  629: 398,
#  630: 399,
#  632: 400,
#  633: 401,
#  637: 402,
#  638: 403,
#  640: 404,
#  641: 405,
#  643: 406,
#  644: 407,
#  645: 408,
#  649: 409,
#  650: 410,
#  652: 411,
#  653: 412,
#  654: 413,
#  656: 414,
#  657: 415,
#  658: 416,
#  660: 417,
#  661: 418,
#  662: 419,
#  663: 420,
#  664: 421,
#  665: 422,
#  667: 423,
#  668: 424,
#  669: 425,
#  670: 426,
#  671: 427,
#  673: 428,
#  674: 429,
#  676: 430,
#  677: 431,
#  679: 432,
#  680: 433,
#  681: 434,
#  682: 435,
#  683: 436,
#  685: 437,
#  687: 438,
#  689: 439,
#  691: 440,
#  693: 441,
#  694: 442,
#  696: 443,
#  697: 444,
#  699: 445,
#  702: 446,
#  703: 447,
#  705: 448,
#  708: 449,
#  709: 450,
#  710: 451,
#  711: 452,
#  713: 453,
#  714: 454,
#  715: 455,
#  716: 456,
#  718: 457,
#  719: 458,
#  720: 459,
#  722: 460,
#  724: 461,
#  725: 462,
#  727: 463,
#  729: 464,
#  730: 465,
#  731: 466,
#  733: 467,
#  735: 468,
#  736: 469,
#  737: 470,
#  738: 471,
#  739: 472,
#  740: 473,
#  742: 474,
#  743: 475,
#  745: 476,
#  746: 477,
#  747: 478,
#  749: 479,
#  751: 480,
#  752: 481,
#  753: 482,
#  757: 483,
#  758: 484,
#  759: 485,
#  760: 486,
#  764: 487,
#  767: 488,
#  769: 489,
#  770: 490,
#  772: 491,
#  776: 492,
#  777: 493,
#  778: 494,
#  779: 495,
#  780: 496,
#  782: 497,
#  783: 498,
#  784: 499,
#  785: 500,
#  786: 501,
#  789: 502,
#  791: 503,
#  792: 504,
#  794: 505,
#  795: 506,
#  796: 507,
#  798: 508,
#  799: 509,
#  802: 510,
#  803: 511,
#  804: 512,
#  805: 513,
#  806: 514,
#  808: 515,
#  809: 516,
#  811: 517,
#  812: 518,
#  814: 519,
#  815: 520,
#  817: 521,
#  818: 522,
#  819: 523,
#  820: 524,
#  822: 525,
#  824: 526,
#  826: 527,
#  827: 528,
#  830: 529,
#  831: 530,
#  832: 531,
#  833: 532,
#  834: 533,
#  836: 534,
#  840: 535,
#  841: 536,
#  842: 537,
#  844: 538,
#  845: 539,
#  849: 540,
#  851: 541,
#  852: 542,
#  853: 543,
#  859: 544,
#  861: 545,
#  862: 546,
#  863: 547,
#  867: 548,
#  868: 549,
#  869: 550,
#  870: 551,
#  872: 552,
#  873: 553,
#  878: 554,
#  879: 555,
#  881: 556,
#  882: 557,
#  883: 558,
#  884: 559,
#  886: 560,
#  888: 561,
#  890: 562,
#  892: 563,
#  894: 564,
#  895: 565,
#  897: 566,
#  898: 567,
#  899: 568,
#  900: 569,
#  901: 570,
#  902: 571,
#  904: 572,
#  906: 573,
#  907: 574,
#  908: 575,
#  909: 576,
#  910: 577,
#  914: 578,
#  917: 579,
#  918: 580,
#  919: 581,
#  921: 582,
#  923: 583,
#  927: 584,
#  928: 585,
#  929: 586,
#  930: 587,
#  931: 588,
#  932: 589,
#  934: 590,
#  935: 591,
#  937: 592,
#  938: 593,
#  939: 594,
#  940: 595,
#  941: 596,
#  943: 597,
#  947: 598,
#  949: 599,
#  950: 600,
#  951: 601,
#  952: 602,
#  955: 603,
#  956: 604,
#  957: 605,
#  958: 606,
#  960: 607,
#  961: 608,
#  963: 609,
#  964: 610,
#  965: 611,
#  967: 612,
#  970: 613,
#  972: 614,
#  973: 615,
#  974: 616,
#  975: 617,
#  976: 618,
#  978: 619,
#  981: 620,
#  982: 621,
#  983: 622,
#  985: 623,
#  987: 624,
#  988: 625,
#  991: 626,
#  992: 627,
#  993: 628,
#  994: 629,
#  995: 630,
#  997: 631,
#  998: 632,
#  999: 633,
#  1001: 634,
#  1002: 635,
#  1003: 636,
#  1005: 637,
#  1006: 638,
#  1007: 639,
#  1008: 640,
#  1009: 641,
#  1010: 642,
#  1011: 643,
#  1012: 644,
#  1013: 645,
#  1014: 646,
#  1015: 647,
#  1016: 648,
#  1017: 649,
#  1018: 650,
#  1020: 651,
#  1022: 652,
#  1023: 653,
#  1024: 654,
#  1026: 655,
#  1028: 656,
#  1030: 657,
#  1031: 658,
#  1032: 659,
#  1033: 660,
#  1034: 661,
#  1035: 662,
#  1036: 663,
#  1037: 664,
#  1038: 665,
#  1039: 666,
#  1041: 667,
#  1047: 668,
#  1048: 669,
#  1049: 670,
#  1050: 671,
#  1053: 672,
#  1054: 673,
#  1055: 674,
#  1056: 675,
#  1057: 676,
#  1058: 677,
#  1060: 678,
#  1061: 679,
#  1062: 680,
#  1063: 681,
#  1064: 682,
#  1065: 683,
#  1066: 684,
#  1074: 685,
#  1076: 686,
#  1077: 687,
#  1078: 688,
#  1080: 689,
#  1081: 690,
#  1082: 691,
#  1084: 692,
#  1085: 693,
#  1087: 694,
#  1088: 695,
#  1089: 696,
#  1090: 697,
#  1091: 698,
#  1093: 699,
#  1095: 700,
#  1096: 701,
#  1097: 702,
#  1100: 703,
#  1102: 704,
#  1103: 705,
#  1104: 706,
#  1107: 707,
#  1108: 708,
#  1111: 709,
#  1112: 710,
#  1114: 711,
#  1116: 712,
#  1120: 713,
#  1122: 714,
#  1123: 715,
#  1125: 716,
#  1128: 717,
#  1129: 718,
#  1130: 719,
#  1132: 720,
#  1133: 721,
#  1135: 722,
#  1136: 723,
#  1137: 724,
#  1138: 725,
#  1141: 726,
#  1142: 727,
#  1145: 728,
#  1147: 729,
#  1148: 730,
#  1149: 731,
#  1150: 732,
#  1152: 733,
#  1153: 734,
#  1154: 735,
#  1155: 736,
#  1156: 737,
#  1159: 738,
#  1160: 739,
#  1161: 740,
#  1162: 741,
#  1163: 742,
#  1164: 743,
#  1165: 744,
#  1166: 745,
#  1167: 746,
#  1168: 747,
#  1169: 748,
#  1174: 749,
#  1177: 750,
#  1178: 751,
#  1182: 752,
#  1183: 753,
#  1188: 754,
#  1189: 755,
#  1190: 756,
#  1193: 757,
#  1194: 758,
#  1195: 759,
#  1196: 760,
#  1197: 761,
#  1198: 762,
#  1199: 763,
#  1200: 764,
#  1201: 765,
#  1202: 766,
#  1204: 767,
#  1206: 768,
#  1207: 769,
#  1210: 770,
#  1212: 771,
#  1213: 772,
#  1214: 773,
#  1215: 774,
#  1216: 775,
#  1217: 776,
#  1218: 777,
#  1220: 778,
#  1221: 779,
#  1222: 780,
#  1227: 781,
#  1228: 782,
#  1229: 783,
#  1230: 784,
#  1232: 785,
#  1233: 786,
#  1234: 787,
#  1235: 788,
#  1236: 789,
#  1239: 790,
#  1241: 791,
#  1242: 792,
#  1243: 793,
#  1245: 794,
#  1247: 795,
#  1248: 796,
#  1249: 797,
#  1250: 798,
#  1253: 799,
#  1254: 800,
#  1255: 801,
#  1256: 802,
#  1257: 803,
#  1258: 804,
#  1259: 805,
#  1261: 806,
#  1262: 807,
#  1263: 808,
#  1264: 809,
#  1266: 810,
#  1268: 811,
#  1269: 812,
#  1270: 813,
#  1272: 814,
#  1274: 815,
#  1277: 816,
#  1278: 817,
#  1280: 818,
#  1283: 819,
#  1284: 820,
#  1285: 821,
#  1287: 822,
#  1290: 823,
#  1291: 824,
#  1293: 825,
#  1294: 826,
#  1295: 827,
#  1296: 828,
#  1297: 829,
#  1299: 830,
#  1300: 831,
#  1302: 832,
#  1303: 833,
#  1304: 834,
#  1305: 835,
#  1306: 836,
#  1307: 837,
#  1310: 838,
#  1311: 839,
#  1312: 840,
#  1313: 841,
#  1314: 842,
#  1316: 843,
#  1317: 844,
#  1320: 845,
#  1322: 846,
#  1323: 847,
#  1324: 848,
#  1326: 849,
#  1327: 850,
#  1328: 851,
#  1330: 852,
#  1332: 853,
#  1333: 854,
#  1334: 855,
#  1335: 856,
#  1336: 857,
#  1337: 858,
#  1339: 859,
#  1341: 860,
#  1342: 861,
#  1344: 862,
#  1345: 863,
#  1347: 864,
#  1348: 865,
#  1349: 866,
#  1350: 867,
#  1351: 868,
#  1352: 869,
#  1353: 870,
#  1354: 871,
#  1357: 872,
#  1358: 873,
#  1361: 874,
#  1363: 875,
#  1366: 876,
#  1367: 877,
#  1370: 878,
#  1371: 879,
#  1372: 880,
#  1377: 881,
#  1378: 882,
#  1379: 883,
#  1382: 884,
#  1386: 885,
#  1388: 886,
#  1389: 887,
#  1392: 888,
#  1393: 889,
#  1396: 890,
#  1398: 891,
#  1402: 892,
#  1404: 893,
#  1405: 894,
#  1406: 895,
#  1407: 896,
#  1408: 897,
#  1409: 898,
#  1411: 899,
#  1413: 900,
#  1417: 901,
#  1418: 902,
#  1422: 903,
#  1423: 904,
#  1424: 905,
#  1425: 906,
#  1426: 907,
#  1427: 908,
#  1428: 909,
#  1430: 910,
#  1431: 911,
#  1432: 912,
#  1433: 913,
#  1434: 914,
#  1438: 915,
#  1439: 916,
#  1440: 917,
#  1442: 918,
#  1444: 919,
#  1445: 920,
#  1446: 921,
#  1447: 922,
#  1448: 923,
#  1449: 924,
#  1450: 925,
#  1454: 926,
#  1455: 927,
#  1456: 928,
#  1457: 929,
#  1458: 930,
#  1460: 931,
#  1461: 932,
#  1462: 933,
#  1463: 934,
#  1465: 935,
#  1468: 936,
#  1470: 937,
#  1472: 938,
#  1473: 939,
#  1474: 940,
#  1475: 941,
#  1476: 942}

# %%
qtl
# Out:
# (56, 255, 465, 472, 616, 1030, 1141, 1247, 1327, 1468)

# %%
allele_effects_table = analyze.generate_allele_effects_table(qtl, alleles, 
                                                allele_effects, saegus_to_tassel_loci)

# %%
allele_effects_table
# Out:
#    locus  tassel_locus  alpha_allele  alpha_effect  beta_allele  beta_effect  \
# 0     56            37             1      2.281269            3     0.483576
# 1    255           148             3      1.563291            1     0.674750
# 2    465           288             1      0.688840            3     1.529349
# 3    472           292             1      1.211195            0     0.084054
# 4    616           390             1      0.190864            3     0.289322
# 5   1030           657             3      0.495063            1     0.260346
# 6   1141           726             1      1.123208            2     1.063125
# 7   1247           795             3      0.056021            1     3.863567
# 8   1327           850             0      3.507663            2     0.791271
# 9   1468           936             2      1.209494            0     0.769592
#
#    difference
# 0    1.797694
# 1    0.888541
# 2    0.840509
# 3    1.127141
# 4    0.098458
# 5    0.234717
# 6    0.060083
# 7    3.807546
# 8    2.716392
# 9    0.439902

# %%
saegus_to_tassel_loci = loci_conversions['saegus_to_tassel']

# %%
saegus_to_tassel_loci

# %%
len(saegus_to_tassel_loci)
# Out:
# 943

# %%
allele_effects_table
# Out:
#    locus  tassel_locus  alpha_allele  alpha_effect  beta_allele  beta_effect  \
# 0     56            37             1      2.281269            3     0.483576
# 1    255           148             3      1.563291            1     0.674750
# 2    465           288             1      0.688840            3     1.529349
# 3    472           292             1      1.211195            0     0.084054
# 4    616           390             1      0.190864            3     0.289322
# 5   1030           657             3      0.495063            1     0.260346
# 6   1141           726             1      1.123208            2     1.063125
# 7   1247           795             3      0.056021            1     3.863567
# 8   1327           850             0      3.507663            2     0.791271
# 9   1468           936             2      1.209494            0     0.769592
#
#    difference
# 0    1.797694
# 1    0.888541
# 2    0.840509
# 3    1.127141
# 4    0.098458
# 5    0.234717
# 6    0.060083
# 7    3.807546
# 8    2.716392
# 9    0.439902

# %%
remapped_loci = [saegus_to_tassel_loci[locus] for locus in allele_effects_table['locus']]

# %%
allele_effects_table
# Out:
#    locus  tassel_locus  alpha_allele  alpha_effect  beta_allele  beta_effect  \
# 0     56            37             1      2.281269            3     0.483576
# 1    255           148             3      1.563291            1     0.674750
# 2    465           288             1      0.688840            3     1.529349
# 3    472           292             1      1.211195            0     0.084054
# 4    616           390             1      0.190864            3     0.289322
# 5   1030           657             3      0.495063            1     0.260346
# 6   1141           726             1      1.123208            2     1.063125
# 7   1247           795             3      0.056021            1     3.863567
# 8   1327           850             0      3.507663            2     0.791271
# 9   1468           936             2      1.209494            0     0.769592
#
#    difference
# 0    1.797694
# 1    0.888541
# 2    0.840509
# 3    1.127141
# 4    0.098458
# 5    0.234717
# 6    0.060083
# 7    3.807546
# 8    2.716392
# 9    0.439902

# %%
import h5py

# %%
afs = h5py.File('demonstration_allele_frequency_storage.h5')

# %%
np.array(afs['demonstration']['0']['500']['axis1'])
# Out:
# array([   0,    1,    2, ..., 1475, 1476, 1477], dtype=int64)

# %%
pd.DataFrame(np.array(afs['demonstration/0/500/block0_values']))
# Out:
#         0      1    2      3
# 0     2.0  0.000  1.0  1.000
# 1     3.0  0.129  1.0  0.871
# 2     1.0  0.130  3.0  0.870
# 3     2.0  0.120  0.0  0.880
# 4     0.0  0.049  2.0  0.951
# 5     2.0  0.209  0.0  0.791
# 6     2.0  0.235  0.0  0.765
# 7     1.0  0.000  3.0  1.000
# 8     2.0  0.093  0.0  0.907
# 9     3.0  0.000  1.0  1.000
# 10    3.0  0.400  1.0  0.600
# 11    3.0  0.000  1.0  1.000
# 12    1.0  0.382  3.0  0.618
# 13    0.0  0.100  2.0  0.900
# 14    0.0  0.092  3.0  0.908
# 15    1.0  0.389  3.0  0.611
# 16    3.0  0.116  2.0  0.884
# 17    3.0  0.000  2.0  1.000
# 18    0.0  0.000  2.0  1.000
# 19    4.0  0.000  5.0  1.000
# 20    0.0  0.386  3.0  0.614
# 21    1.0  0.138  2.0  0.862
# 22    3.0  0.000  2.0  1.000
# 23    5.0  0.434  4.0  0.566
# 24    3.0  0.064  1.0  0.936
# 25    0.0  0.251  2.0  0.749
# 26    0.0  0.066  3.0  0.934
# 27    1.0  0.060  0.0  0.940
# 28    1.0  0.000  2.0  1.000
# 29    0.0  0.423  2.0  0.577
# ...   ...    ...  ...    ...
# 1448  0.0  0.259  3.0  0.741
# 1449  3.0  0.375  0.0  0.625
# 1450  2.0  0.196  0.0  0.804
# 1451  3.0  0.000  1.0  1.000
# 1452  5.0  0.000  4.0  1.000
# 1453  3.0  0.000  1.0  1.000
# 1454  1.0  0.126  3.0  0.874
# 1455  2.0  0.481  3.0  0.519
# 1456  2.0  0.122  0.0  0.878
# 1457  0.0  0.054  2.0  0.946
# 1458  0.0  0.483  1.0  0.517
# 1459  5.0  0.000  4.0  1.000
# 1460  0.0  0.114  3.0  0.886
# 1461  1.0  0.069  2.0  0.931
# 1462  3.0  0.128  1.0  0.872
# 1463  3.0  0.246  1.0  0.754
# 1464  1.0  0.000  3.0  1.000
# 1465  0.0  0.122  2.0  0.878
# 1466  3.0  0.000  1.0  1.000
# 1467  0.0  0.000  2.0  1.000
# 1468  0.0  0.281  2.0  0.719
# 1469  2.0  0.000  1.0  1.000
# 1470  0.0  0.258  2.0  0.742
# 1471  3.0  0.000  0.0  1.000
# 1472  0.0  0.138  1.0  0.862
# 1473  1.0  0.071  0.0  0.929
# 1474  2.0  0.243  0.0  0.757
# 1475  0.0  0.260  1.0  0.740
# 1476  0.0  0.126  3.0  0.874
# 1477  1.0  0.000  3.0  1.000
#
# [1478 rows x 4 columns]

# %%
afs.close()

# %%
afd = pd.HDFStore('demonstration_allele_frequency_storage.h5')

# %%
afd['/demonstration/0/500']
# Out:
#       minor_allele  minor_frequency  major_allele  major_frequency
# 0              2.0            0.000           1.0            1.000
# 1              3.0            0.129           1.0            0.871
# 2              1.0            0.130           3.0            0.870
# 3              2.0            0.120           0.0            0.880
# 4              0.0            0.049           2.0            0.951
# 5              2.0            0.209           0.0            0.791
# 6              2.0            0.235           0.0            0.765
# 7              1.0            0.000           3.0            1.000
# 8              2.0            0.093           0.0            0.907
# 9              3.0            0.000           1.0            1.000
# 10             3.0            0.400           1.0            0.600
# 11             3.0            0.000           1.0            1.000
# 12             1.0            0.382           3.0            0.618
# 13             0.0            0.100           2.0            0.900
# 14             0.0            0.092           3.0            0.908
# 15             1.0            0.389           3.0            0.611
# 16             3.0            0.116           2.0            0.884
# 17             3.0            0.000           2.0            1.000
# 18             0.0            0.000           2.0            1.000
# 19             4.0            0.000           5.0            1.000
# 20             0.0            0.386           3.0            0.614
# 21             1.0            0.138           2.0            0.862
# 22             3.0            0.000           2.0            1.000
# 23             5.0            0.434           4.0            0.566
# 24             3.0            0.064           1.0            0.936
# 25             0.0            0.251           2.0            0.749
# 26             0.0            0.066           3.0            0.934
# 27             1.0            0.060           0.0            0.940
# 28             1.0            0.000           2.0            1.000
# 29             0.0            0.423           2.0            0.577
# ...            ...              ...           ...              ...
# 1448           0.0            0.259           3.0            0.741
# 1449           3.0            0.375           0.0            0.625
# 1450           2.0            0.196           0.0            0.804
# 1451           3.0            0.000           1.0            1.000
# 1452           5.0            0.000           4.0            1.000
# 1453           3.0            0.000           1.0            1.000
# 1454           1.0            0.126           3.0            0.874
# 1455           2.0            0.481           3.0            0.519
# 1456           2.0            0.122           0.0            0.878
# 1457           0.0            0.054           2.0            0.946
# 1458           0.0            0.483           1.0            0.517
# 1459           5.0            0.000           4.0            1.000
# 1460           0.0            0.114           3.0            0.886
# 1461           1.0            0.069           2.0            0.931
# 1462           3.0            0.128           1.0            0.872
# 1463           3.0            0.246           1.0            0.754
# 1464           1.0            0.000           3.0            1.000
# 1465           0.0            0.122           2.0            0.878
# 1466           3.0            0.000           1.0            1.000
# 1467           0.0            0.000           2.0            1.000
# 1468           0.0            0.281           2.0            0.719
# 1469           2.0            0.000           1.0            1.000
# 1470           0.0            0.258           2.0            0.742
# 1471           3.0            0.000           0.0            1.000
# 1472           0.0            0.138           1.0            0.862
# 1473           1.0            0.071           0.0            0.929
# 1474           2.0            0.243           0.0            0.757
# 1475           0.0            0.260           1.0            0.740
# 1476           0.0            0.126           3.0            0.874
# 1477           1.0            0.000           3.0            1.000
#
# [1478 rows x 4 columns]

# %%
expanded = analyze.remap_ae_table_loci(allele_effects_table, saegus_to_tassel_loci)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    3912                 blocks = [make_block(values=blocks[0],
# -> 3913                                      placement=slice(0, len(axes[0])))]
#    3914
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2460
# -> 2461     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2462
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, values, placement, ndim, fastpath)
#      83                              'implies %d' % (len(self.values),
# ---> 84                                              len(self.mgr_locs)))
#      85
#
# ValueError: Wrong number of items passed 943, placement implies 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-85bacd22f1ab> in <module>()
# ----> 1 expanded = analyze.remap_ae_table_loci(allele_effects_table, saegus_to_tassel_loci)
#
# C:\Anaconda3\lib\site-packages\saegus\analyze.py in remap_ae_table_loci(allele_effect_table, saegus_to_tassel_loci)
#    1595     expanded_ae_table = pd.DataFrame(np.zeros(
#    1596         (len(saegus_to_tassel_loci), 6)).T,
# -> 1597                                               columns=['difference'])
#    1598
#    1599     for qtlocus in remapped_ae_table.locus:
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     252             else:
#     253                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 254                                          copy=copy)
#     255         elif isinstance(data, (list, types.GeneratorType)):
#     256             if isinstance(data, types.GeneratorType):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     429             values = _possibly_infer_to_datetimelike(values)
#     430
# --> 431         return create_block_manager_from_blocks([values], [columns, index])
#     432
#     433     @property
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    3920         blocks = [getattr(b, 'values', b) for b in blocks]
#    3921         tot_items = sum(b.shape[0] for b in blocks)
# -> 3922         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    3923
#    3924
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals.py in construction_error(tot_items, block_shape, axes, e)
#    3897         raise ValueError("Empty data passed with indices specified.")
#    3898     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 3899         passed, implied))
#    3900
#    3901
#
# ValueError: Shape of passed values is (943, 6), indices imply (1, 6)

# %%
expanded

# %%
allele_frequencies = pd.HDFStore('demonstration_storage.h5', mode='r')

# %%
afrqs = allele_frequencies['/demonstration/0/500']

# %%
import h5py

# %%
h5pyaf = h5py.File('demonstration_allele_frequency_storage.h5')

# %%
list(h5pyaf.keys())
# Out:
# ['demonstration']

# %%
for k in list(h5pyaf["demonstration/0/500/axis0/"].values()):
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-6df4bfad0f64> in <module>()
# ----> 1 for k in list(h5pyaf["demonstration/0/500/axis0/"].values()):
#       2     print(k)
#
# AttributeError: 'Dataset' object has no attribute 'values'

# %%
som = h5pyaf['demonstration/0/500/']

# %%
np.array(som['axis1'])
# Out:
# array([   0,    1,    2, ..., 1475, 1476, 1477], dtype=int64)

# %%
list(som.keys())
# Out:
# ['axis0', 'axis1', 'block0_items', 'block0_values']

# %%
thing = list(som['axis0'])[0].decode()

# %%
thing
# Out:
# 'minor_allele'

# %%
thing?

# %%
list(som['block0_values'].attrs)
# Out:
# ['CLASS', 'VERSION', 'TITLE', 'FLAVOR', 'transposed']

# %%
list(som['block0_values'])
# Out:
# [array([ 2.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.129,  1.   ,  0.871]),
#  array([ 1.  ,  0.13,  3.  ,  0.87]),
#  array([ 2.  ,  0.12,  0.  ,  0.88]),
#  array([ 0.   ,  0.049,  2.   ,  0.951]),
#  array([ 2.   ,  0.209,  0.   ,  0.791]),
#  array([ 2.   ,  0.235,  0.   ,  0.765]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 2.   ,  0.093,  0.   ,  0.907]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3. ,  0.4,  1. ,  0.6]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.382,  3.   ,  0.618]),
#  array([ 0. ,  0.1,  2. ,  0.9]),
#  array([ 0.   ,  0.092,  3.   ,  0.908]),
#  array([ 1.   ,  0.389,  3.   ,  0.611]),
#  array([ 3.   ,  0.116,  2.   ,  0.884]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 0.   ,  0.386,  3.   ,  0.614]),
#  array([ 1.   ,  0.138,  2.   ,  0.862]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 5.   ,  0.434,  4.   ,  0.566]),
#  array([ 3.   ,  0.064,  1.   ,  0.936]),
#  array([ 0.   ,  0.251,  2.   ,  0.749]),
#  array([ 0.   ,  0.066,  3.   ,  0.934]),
#  array([ 1.  ,  0.06,  0.  ,  0.94]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.423,  2.   ,  0.577]),
#  array([ 0.   ,  0.137,  2.   ,  0.863]),
#  array([ 1.   ,  0.239,  0.   ,  0.761]),
#  array([ 1.   ,  0.125,  3.   ,  0.875]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 3.   ,  0.202,  1.   ,  0.798]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.359,  1.   ,  0.641]),
#  array([ 1.   ,  0.098,  3.   ,  0.902]),
#  array([ 4.   ,  0.068,  5.   ,  0.932]),
#  array([ 2.   ,  0.046,  0.   ,  0.954]),
#  array([ 3.  ,  0.13,  1.  ,  0.87]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.117,  2.   ,  0.883]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 2.   ,  0.477,  0.   ,  0.523]),
#  array([ 1.   ,  0.254,  3.   ,  0.746]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.155,  1.   ,  0.845]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 3.   ,  0.138,  1.   ,  0.862]),
#  array([ 1.   ,  0.243,  0.   ,  0.757]),
#  array([ 1.  ,  0.37,  0.  ,  0.63]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.069,  1.   ,  0.931]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.139,  1.   ,  0.861]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.262,  2.   ,  0.738]),
#  array([ 0.   ,  0.197,  2.   ,  0.803]),
#  array([ 0.   ,  0.103,  2.   ,  0.897]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.144,  2.   ,  0.856]),
#  array([ 0.  ,  0.08,  2.  ,  0.92]),
#  array([ 0.   ,  0.492,  2.   ,  0.508]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 4.   ,  0.396,  5.   ,  0.604]),
#  array([ 1.   ,  0.111,  2.   ,  0.889]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.   ,  0.061,  2.   ,  0.939]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 3. ,  0.1,  0. ,  0.9]),
#  array([ 1.   ,  0.405,  3.   ,  0.595]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.   ,  0.103,  2.   ,  0.897]),
#  array([ 0.   ,  0.058,  3.   ,  0.942]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.  ,  0.25,  2.  ,  0.75]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 3.  ,  0.47,  1.  ,  0.53]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.118,  1.   ,  0.882]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 5.   ,  0.136,  4.   ,  0.864]),
#  array([ 3.   ,  0.126,  1.   ,  0.874]),
#  array([ 1.,  0.,  0.,  1.]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.319,  2.   ,  0.681]),
#  array([ 3.   ,  0.117,  1.   ,  0.883]),
#  array([ 2.   ,  0.115,  1.   ,  0.885]),
#  array([ 0.   ,  0.105,  2.   ,  0.895]),
#  array([ 0.   ,  0.063,  1.   ,  0.937]),
#  array([ 3.   ,  0.116,  1.   ,  0.884]),
#  array([ 0.   ,  0.114,  2.   ,  0.886]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 2.  ,  0.12,  0.  ,  0.88]),
#  array([ 3.   ,  0.044,  1.   ,  0.956]),
#  array([ 1.,  0.,  0.,  1.]),
#  array([ 1.   ,  0.119,  2.   ,  0.881]),
#  array([ 1.   ,  0.494,  3.   ,  0.506]),
#  array([ 2.  ,  0.38,  0.  ,  0.62]),
#  array([ 3. ,  0.1,  2. ,  0.9]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.   ,  0.115,  1.   ,  0.885]),
#  array([ 5.   ,  0.265,  4.   ,  0.735]),
#  array([ 1.   ,  0.057,  3.   ,  0.943]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 1.   ,  0.178,  3.   ,  0.822]),
#  array([ 3.   ,  0.127,  1.   ,  0.873]),
#  array([ 0.   ,  0.056,  2.   ,  0.944]),
#  array([ 3.   ,  0.255,  0.   ,  0.745]),
#  array([ 3.   ,  0.056,  2.   ,  0.944]),
#  array([ 3.   ,  0.119,  1.   ,  0.881]),
#  array([ 2.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.118,  1.   ,  0.882]),
#  array([ 1.   ,  0.496,  3.   ,  0.504]),
#  array([ 3.   ,  0.257,  1.   ,  0.743]),
#  array([ 2.   ,  0.106,  0.   ,  0.894]),
#  array([ 0.  ,  0.12,  2.  ,  0.88]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.144,  1.   ,  0.856]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 1.  ,  0.34,  3.  ,  0.66]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 3.   ,  0.239,  1.   ,  0.761]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 1.   ,  0.123,  3.   ,  0.877]),
#  array([ 3.   ,  0.116,  1.   ,  0.884]),
#  array([ 0.   ,  0.209,  2.   ,  0.791]),
#  array([ 3.   ,  0.132,  2.   ,  0.868]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.   ,  0.249,  1.   ,  0.751]),
#  array([ 2.   ,  0.113,  0.   ,  0.887]),
#  array([ 2.   ,  0.491,  0.   ,  0.509]),
#  array([ 3.  ,  0.25,  1.  ,  0.75]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.107,  1.   ,  0.893]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.152,  3.   ,  0.848]),
#  array([ 3.   ,  0.393,  1.   ,  0.607]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 0.   ,  0.347,  2.   ,  0.653]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.252,  1.   ,  0.748]),
#  array([ 3.   ,  0.244,  2.   ,  0.756]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.378,  0.   ,  0.622]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.  ,  0.05,  1.  ,  0.95]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.209,  2.   ,  0.791]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 3.  ,  0.13,  1.  ,  0.87]),
#  array([ 2.  ,  0.25,  3.  ,  0.75]),
#  array([ 0.   ,  0.139,  1.   ,  0.861]),
#  array([ 1.   ,  0.284,  0.   ,  0.716]),
#  array([ 1.   ,  0.497,  3.   ,  0.503]),
#  array([ 1.   ,  0.137,  3.   ,  0.863]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.137,  1.   ,  0.863]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.128,  2.   ,  0.872]),
#  array([ 1.   ,  0.116,  3.   ,  0.884]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.081,  1.   ,  0.919]),
#  array([ 2.   ,  0.364,  0.   ,  0.636]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.062,  1.   ,  0.938]),
#  array([ 2.   ,  0.431,  0.   ,  0.569]),
#  array([ 1.   ,  0.239,  3.   ,  0.761]),
#  array([ 0.   ,  0.254,  2.   ,  0.746]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 1.  ,  0.12,  0.  ,  0.88]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.126,  1.   ,  0.874]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.124,  1.   ,  0.876]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.255,  1.   ,  0.745]),
#  array([ 0.   ,  0.064,  2.   ,  0.936]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 0.   ,  0.111,  2.   ,  0.889]),
#  array([ 3.   ,  0.339,  1.   ,  0.661]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 0.   ,  0.264,  2.   ,  0.736]),
#  array([ 3.   ,  0.142,  1.   ,  0.858]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.247,  0.   ,  0.753]),
#  array([ 0.   ,  0.245,  2.   ,  0.755]),
#  array([ 2.   ,  0.248,  1.   ,  0.752]),
#  array([ 3.   ,  0.081,  2.   ,  0.919]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.384,  0.   ,  0.616]),
#  array([ 0.   ,  0.065,  1.   ,  0.935]),
#  array([ 3.   ,  0.147,  1.   ,  0.853]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 1.   ,  0.497,  3.   ,  0.503]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 2.   ,  0.138,  1.   ,  0.862]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.479,  3.   ,  0.521]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 2.   ,  0.131,  0.   ,  0.869]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.133,  2.   ,  0.867]),
#  array([ 1.   ,  0.135,  3.   ,  0.865]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.052,  1.   ,  0.948]),
#  array([ 3.   ,  0.247,  2.   ,  0.753]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 2.   ,  0.136,  0.   ,  0.864]),
#  array([ 0.   ,  0.051,  1.   ,  0.949]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.   ,  0.249,  1.   ,  0.751]),
#  array([ 3.  ,  0.12,  2.  ,  0.88]),
#  array([ 2.   ,  0.141,  3.   ,  0.859]),
#  array([ 1.   ,  0.258,  3.   ,  0.742]),
#  array([ 0.  ,  0.12,  2.  ,  0.88]),
#  array([ 1.   ,  0.494,  3.   ,  0.506]),
#  array([ 2.   ,  0.218,  0.   ,  0.782]),
#  array([ 0.  ,  0.24,  2.  ,  0.76]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.132,  3.   ,  0.868]),
#  array([ 1.   ,  0.186,  3.   ,  0.814]),
#  array([ 0.  ,  0.11,  2.  ,  0.89]),
#  array([ 3.   ,  0.068,  1.   ,  0.932]),
#  array([ 0.  ,  0.23,  1.  ,  0.77]),
#  array([ 0.   ,  0.261,  3.   ,  0.739]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.129,  2.   ,  0.871]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.113,  2.   ,  0.887]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 5.   ,  0.241,  4.   ,  0.759]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.064,  0.   ,  0.936]),
#  array([ 2.   ,  0.058,  0.   ,  0.942]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 2.  ,  0.37,  1.  ,  0.63]),
#  array([ 3.   ,  0.092,  0.   ,  0.908]),
#  array([ 1.   ,  0.113,  2.   ,  0.887]),
#  array([ 0.   ,  0.033,  2.   ,  0.967]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.379,  2.   ,  0.621]),
#  array([ 1.   ,  0.131,  2.   ,  0.869]),
#  array([ 1.   ,  0.378,  2.   ,  0.622]),
#  array([ 1.   ,  0.389,  3.   ,  0.611]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.127,  1.   ,  0.873]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.385,  2.   ,  0.615]),
#  array([ 3.   ,  0.407,  1.   ,  0.593]),
#  array([ 5.   ,  0.329,  4.   ,  0.671]),
#  array([ 0.   ,  0.393,  2.   ,  0.607]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.362,  3.   ,  0.638]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.   ,  0.136,  1.   ,  0.864]),
#  array([ 3.   ,  0.125,  1.   ,  0.875]),
#  array([ 1.   ,  0.134,  3.   ,  0.866]),
#  array([ 0.   ,  0.243,  3.   ,  0.757]),
#  array([ 2.   ,  0.263,  1.   ,  0.737]),
#  array([ 1.   ,  0.114,  2.   ,  0.886]),
#  array([ 1.   ,  0.485,  0.   ,  0.515]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 5.   ,  0.335,  4.   ,  0.665]),
#  array([ 2.   ,  0.139,  0.   ,  0.861]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.251,  3.   ,  0.749]),
#  array([ 2.   ,  0.058,  1.   ,  0.942]),
#  array([ 1.   ,  0.278,  3.   ,  0.722]),
#  array([ 0.   ,  0.127,  2.   ,  0.873]),
#  array([ 4.   ,  0.147,  5.   ,  0.853]),
#  array([ 2.   ,  0.131,  0.   ,  0.869]),
#  array([ 5.   ,  0.132,  4.   ,  0.868]),
#  array([ 5.   ,  0.076,  4.   ,  0.924]),
#  array([ 1.   ,  0.135,  2.   ,  0.865]),
#  array([ 3.   ,  0.125,  1.   ,  0.875]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.235,  1.   ,  0.765]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.,  0.,  3.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 3.   ,  0.126,  2.   ,  0.874]),
#  array([ 2.   ,  0.145,  0.   ,  0.855]),
#  array([ 0.   ,  0.137,  1.   ,  0.863]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.   ,  0.393,  1.   ,  0.607]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 3.  ,  0.24,  1.  ,  0.76]),
#  array([ 2.  ,  0.39,  0.  ,  0.61]),
#  array([ 0.   ,  0.118,  2.   ,  0.882]),
#  array([ 3.   ,  0.131,  2.   ,  0.869]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 4.   ,  0.164,  5.   ,  0.836]),
#  array([ 2.   ,  0.229,  1.   ,  0.771]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 3.  ,  0.24,  1.  ,  0.76]),
#  array([ 0.   ,  0.321,  2.   ,  0.679]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.343,  0.   ,  0.657]),
#  array([ 0.   ,  0.057,  1.   ,  0.943]),
#  array([ 3.   ,  0.119,  1.   ,  0.881]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.487,  3.   ,  0.513]),
#  array([ 3.   ,  0.269,  1.   ,  0.731]),
#  array([ 3.   ,  0.059,  1.   ,  0.941]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.102,  2.   ,  0.898]),
#  array([ 1.   ,  0.083,  0.   ,  0.917]),
#  array([ 3.   ,  0.139,  1.   ,  0.861]),
#  array([ 4.   ,  0.258,  5.   ,  0.742]),
#  array([ 0.   ,  0.312,  3.   ,  0.688]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 0.  ,  0.24,  2.  ,  0.76]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.   ,  0.238,  3.   ,  0.762]),
#  array([ 0.   ,  0.045,  2.   ,  0.955]),
#  array([ 1.   ,  0.371,  2.   ,  0.629]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.124,  2.   ,  0.876]),
#  array([ 2.   ,  0.265,  1.   ,  0.735]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 0.   ,  0.224,  1.   ,  0.776]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 0.   ,  0.396,  2.   ,  0.604]),
#  array([ 1.   ,  0.264,  0.   ,  0.736]),
#  array([ 1.   ,  0.395,  2.   ,  0.605]),
#  array([ 3.   ,  0.121,  2.   ,  0.879]),
#  array([ 2.   ,  0.112,  0.   ,  0.888]),
#  array([ 2.   ,  0.261,  0.   ,  0.739]),
#  array([ 1.   ,  0.247,  2.   ,  0.753]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 1.   ,  0.191,  2.   ,  0.809]),
#  array([ 0.   ,  0.063,  1.   ,  0.937]),
#  array([ 1.   ,  0.115,  3.   ,  0.885]),
#  array([ 1.   ,  0.068,  3.   ,  0.932]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 2.  ,  0.39,  0.  ,  0.61]),
#  array([ 0.   ,  0.136,  2.   ,  0.864]),
#  array([ 0.  ,  0.26,  1.  ,  0.74]),
#  array([ 0.   ,  0.121,  3.   ,  0.879]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 1.  ,  0.14,  2.  ,  0.86]),
#  array([ 0.   ,  0.187,  2.   ,  0.813]),
#  array([ 3.   ,  0.266,  2.   ,  0.734]),
#  array([ 1.   ,  0.398,  3.   ,  0.602]),
#  array([ 3.   ,  0.112,  0.   ,  0.888]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.241,  1.   ,  0.759]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 5.   ,  0.257,  4.   ,  0.743]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.147,  1.   ,  0.853]),
#  array([ 1.   ,  0.376,  2.   ,  0.624]),
#  array([ 1.   ,  0.046,  3.   ,  0.954]),
#  array([ 0.   ,  0.074,  3.   ,  0.926]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 3.   ,  0.118,  1.   ,  0.882]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 2.   ,  0.122,  3.   ,  0.878]),
#  array([ 2.   ,  0.496,  0.   ,  0.504]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.147,  3.   ,  0.853]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.243,  1.   ,  0.757]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.113,  3.   ,  0.887]),
#  array([ 0.   ,  0.144,  2.   ,  0.856]),
#  array([ 2.   ,  0.236,  0.   ,  0.764]),
#  array([ 1.   ,  0.311,  3.   ,  0.689]),
#  array([ 3.   ,  0.119,  0.   ,  0.881]),
#  array([ 2.   ,  0.371,  0.   ,  0.629]),
#  array([ 3.   ,  0.124,  1.   ,  0.876]),
#  array([ 4.  ,  0.12,  5.  ,  0.88]),
#  array([ 0.   ,  0.249,  2.   ,  0.751]),
#  array([ 3.   ,  0.129,  0.   ,  0.871]),
#  array([ 0.   ,  0.124,  2.   ,  0.876]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.122,  2.   ,  0.878]),
#  array([ 2.   ,  0.124,  1.   ,  0.876]),
#  array([ 0.   ,  0.109,  3.   ,  0.891]),
#  array([ 2.  ,  0.11,  1.  ,  0.89]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.   ,  0.114,  0.   ,  0.886]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.141,  0.   ,  0.859]),
#  array([ 0.   ,  0.283,  2.   ,  0.717]),
#  array([ 1.   ,  0.233,  3.   ,  0.767]),
#  array([ 3.  ,  0.18,  1.  ,  0.82]),
#  array([ 3.   ,  0.238,  1.   ,  0.762]),
#  array([ 1.   ,  0.129,  3.   ,  0.871]),
#  array([ 3.  ,  0.11,  1.  ,  0.89]),
#  array([ 3.   ,  0.355,  2.   ,  0.645]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 3.   ,  0.265,  1.   ,  0.735]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 2.   ,  0.243,  1.   ,  0.757]),
#  array([ 0.   ,  0.132,  2.   ,  0.868]),
#  array([ 2.   ,  0.224,  0.   ,  0.776]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 1.  ,  0.13,  3.  ,  0.87]),
#  array([ 3.   ,  0.124,  1.   ,  0.876]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.   ,  0.269,  1.   ,  0.731]),
#  array([ 3.  ,  0.13,  1.  ,  0.87]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.   ,  0.362,  0.   ,  0.638]),
#  array([ 0.   ,  0.283,  1.   ,  0.717]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 2.   ,  0.124,  1.   ,  0.876]),
#  array([ 0.   ,  0.127,  3.   ,  0.873]),
#  array([ 2.,  0.,  3.,  1.]),
#  array([ 4.   ,  0.066,  5.   ,  0.934]),
#  array([ 3.   ,  0.058,  1.   ,  0.942]),
#  array([ 3.  ,  0.17,  1.  ,  0.83]),
#  array([ 0.   ,  0.125,  2.   ,  0.875]),
#  array([ 0.   ,  0.377,  2.   ,  0.623]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.251,  3.   ,  0.749]),
#  array([ 1.   ,  0.305,  2.   ,  0.695]),
#  array([ 2.   ,  0.245,  0.   ,  0.755]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 3.  ,  0.16,  1.  ,  0.84]),
#  array([ 1.   ,  0.115,  3.   ,  0.885]),
#  array([ 0.   ,  0.136,  2.   ,  0.864]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.094,  0.   ,  0.906]),
#  array([ 2.   ,  0.269,  0.   ,  0.731]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.394,  2.   ,  0.606]),
#  array([ 0.   ,  0.312,  1.   ,  0.688]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.  ,  0.27,  0.  ,  0.73]),
#  array([ 2.  ,  0.43,  0.  ,  0.57]),
#  array([ 0.   ,  0.125,  2.   ,  0.875]),
#  array([ 1.   ,  0.202,  3.   ,  0.798]),
#  array([ 2.   ,  0.146,  0.   ,  0.854]),
#  array([ 2.   ,  0.129,  3.   ,  0.871]),
#  array([ 2.   ,  0.246,  1.   ,  0.754]),
#  array([ 2.   ,  0.141,  3.   ,  0.859]),
#  array([ 2.   ,  0.099,  3.   ,  0.901]),
#  array([ 0.   ,  0.129,  1.   ,  0.871]),
#  array([ 2.   ,  0.281,  3.   ,  0.719]),
#  array([ 3.   ,  0.347,  1.   ,  0.653]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.478,  0.   ,  0.522]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.226,  2.   ,  0.774]),
#  array([ 3.   ,  0.095,  2.   ,  0.905]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 5.   ,  0.116,  4.   ,  0.884]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 1.   ,  0.261,  3.   ,  0.739]),
#  array([ 3.   ,  0.072,  1.   ,  0.928]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.062,  1.   ,  0.938]),
#  array([ 0.   ,  0.258,  2.   ,  0.742]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.225,  3.   ,  0.775]),
#  array([ 0.   ,  0.128,  2.   ,  0.872]),
#  array([ 0.  ,  0.13,  2.  ,  0.87]),
#  array([ 2.   ,  0.443,  0.   ,  0.557]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.391,  2.   ,  0.609]),
#  array([ 2.   ,  0.382,  3.   ,  0.618]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.104,  1.   ,  0.896]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.359,  3.   ,  0.641]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.387,  3.   ,  0.613]),
#  array([ 3.   ,  0.256,  1.   ,  0.744]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.097,  3.   ,  0.903]),
#  array([ 0.  ,  0.11,  2.  ,  0.89]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.467,  1.   ,  0.533]),
#  array([ 2.  ,  0.37,  0.  ,  0.63]),
#  array([ 1.   ,  0.116,  2.   ,  0.884]),
#  array([ 1.   ,  0.498,  3.   ,  0.502]),
#  array([ 0.  ,  0.07,  2.  ,  0.93]),
#  array([ 3.   ,  0.119,  0.   ,  0.881]),
#  array([ 2.   ,  0.478,  0.   ,  0.522]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.378,  2.   ,  0.622]),
#  array([ 0.   ,  0.129,  2.   ,  0.871]),
#  array([ 2.   ,  0.405,  0.   ,  0.595]),
#  array([ 0.   ,  0.132,  2.   ,  0.868]),
#  array([ 5.  ,  0.13,  4.  ,  0.87]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.,  0.,  3.,  1.]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.126,  3.   ,  0.874]),
#  array([ 0.   ,  0.237,  2.   ,  0.763]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.   ,  0.499,  0.   ,  0.501]),
#  array([ 1.   ,  0.366,  3.   ,  0.634]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 2.   ,  0.375,  1.   ,  0.625]),
#  array([ 3.   ,  0.072,  0.   ,  0.928]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 2.  ,  0.11,  0.  ,  0.89]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.   ,  0.116,  1.   ,  0.884]),
#  array([ 1.   ,  0.235,  2.   ,  0.765]),
#  array([ 3.   ,  0.067,  2.   ,  0.933]),
#  array([ 1.   ,  0.129,  2.   ,  0.871]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.424,  0.   ,  0.576]),
#  array([ 0.   ,  0.139,  2.   ,  0.861]),
#  array([ 3.   ,  0.131,  1.   ,  0.869]),
#  array([ 1.  ,  0.24,  3.  ,  0.76]),
#  array([ 3.   ,  0.054,  1.   ,  0.946]),
#  array([ 5.  ,  0.13,  4.  ,  0.87]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.404,  3.   ,  0.596]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.395,  2.   ,  0.605]),
#  array([ 2.   ,  0.105,  1.   ,  0.895]),
#  array([ 3.   ,  0.065,  2.   ,  0.935]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.105,  1.   ,  0.895]),
#  array([ 2.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.302,  2.   ,  0.698]),
#  array([ 0.   ,  0.386,  2.   ,  0.614]),
#  array([ 1.   ,  0.301,  2.   ,  0.699]),
#  array([ 0.   ,  0.123,  3.   ,  0.877]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 0.   ,  0.146,  2.   ,  0.854]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.271,  3.   ,  0.729]),
#  array([ 2.   ,  0.491,  0.   ,  0.509]),
#  array([ 2.   ,  0.075,  0.   ,  0.925]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.269,  1.   ,  0.731]),
#  array([ 0.   ,  0.121,  2.   ,  0.879]),
#  array([ 0.  ,  0.17,  1.  ,  0.83]),
#  array([ 0.   ,  0.134,  2.   ,  0.866]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 5.  ,  0.12,  4.  ,  0.88]),
#  array([ 3.   ,  0.133,  1.   ,  0.867]),
#  array([ 3.   ,  0.466,  1.   ,  0.534]),
#  array([ 3.   ,  0.493,  1.   ,  0.507]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 2.   ,  0.353,  3.   ,  0.647]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.  ,  0.36,  3.  ,  0.64]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 1.,  0.,  0.,  1.]),
#  array([ 0.   ,  0.104,  2.   ,  0.896]),
#  array([ 0.   ,  0.106,  2.   ,  0.894]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.263,  3.   ,  0.737]),
#  array([ 3.   ,  0.119,  1.   ,  0.881]),
#  array([ 2.   ,  0.122,  1.   ,  0.878]),
#  array([ 1.  ,  0.07,  2.  ,  0.93]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.114,  3.   ,  0.886]),
#  array([ 3.   ,  0.382,  2.   ,  0.618]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 1.,  0.,  0.,  1.]),
#  array([ 3.   ,  0.263,  1.   ,  0.737]),
#  array([ 4.   ,  0.126,  5.   ,  0.874]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 2.   ,  0.222,  1.   ,  0.778]),
#  array([ 1.   ,  0.393,  2.   ,  0.607]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 2.   ,  0.253,  0.   ,  0.747]),
#  array([ 0.   ,  0.125,  2.   ,  0.875]),
#  array([ 2.   ,  0.251,  0.   ,  0.749]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.139,  0.   ,  0.861]),
#  array([ 1.   ,  0.461,  3.   ,  0.539]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 4.   ,  0.062,  5.   ,  0.938]),
#  array([ 3.   ,  0.362,  1.   ,  0.638]),
#  array([ 3.   ,  0.271,  2.   ,  0.729]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 2.  ,  0.05,  3.  ,  0.95]),
#  array([ 3.   ,  0.106,  1.   ,  0.894]),
#  array([ 3.  ,  0.14,  1.  ,  0.86]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 5.  ,  0.05,  4.  ,  0.95]),
#  array([ 5.   ,  0.258,  4.   ,  0.742]),
#  array([ 0.   ,  0.385,  2.   ,  0.615]),
#  array([ 0.   ,  0.318,  2.   ,  0.682]),
#  array([ 1.   ,  0.123,  0.   ,  0.877]),
#  array([ 0.   ,  0.115,  1.   ,  0.885]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 2.   ,  0.132,  3.   ,  0.868]),
#  array([ 1.   ,  0.132,  2.   ,  0.868]),
#  array([ 0.   ,  0.266,  1.   ,  0.734]),
#  array([ 0.   ,  0.209,  1.   ,  0.791]),
#  array([ 0.   ,  0.282,  3.   ,  0.718]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 1.   ,  0.499,  3.   ,  0.501]),
#  array([ 2.   ,  0.125,  1.   ,  0.875]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.203,  2.   ,  0.797]),
#  array([ 0.  ,  0.34,  2.  ,  0.66]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.051,  2.   ,  0.949]),
#  array([ 3.   ,  0.316,  1.   ,  0.684]),
#  array([ 0.   ,  0.403,  2.   ,  0.597]),
#  array([ 4.   ,  0.101,  5.   ,  0.899]),
#  array([ 1.   ,  0.258,  2.   ,  0.742]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.164,  2.   ,  0.836]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.068,  1.   ,  0.932]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.285,  2.   ,  0.715]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.061,  2.   ,  0.939]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 2.  ,  0.05,  0.  ,  0.95]),
#  array([ 3.  ,  0.34,  0.  ,  0.66]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.245,  0.   ,  0.755]),
#  array([ 1.   ,  0.138,  3.   ,  0.862]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 2.   ,  0.483,  0.   ,  0.517]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 3.   ,  0.132,  0.   ,  0.868]),
#  array([ 0.   ,  0.123,  2.   ,  0.877]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.399,  2.   ,  0.601]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.253,  2.   ,  0.747]),
#  array([ 0.   ,  0.357,  1.   ,  0.643]),
#  array([ 0.   ,  0.123,  1.   ,  0.877]),
#  array([ 3.   ,  0.395,  2.   ,  0.605]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.081,  3.   ,  0.919]),
#  array([ 2.   ,  0.337,  1.   ,  0.663]),
#  array([ 3.   ,  0.085,  1.   ,  0.915]),
#  array([ 2.   ,  0.381,  1.   ,  0.619]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.   ,  0.089,  1.   ,  0.911]),
#  array([ 0.   ,  0.238,  1.   ,  0.762]),
#  array([ 2.   ,  0.077,  1.   ,  0.923]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.   ,  0.127,  1.   ,  0.873]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.066,  1.   ,  0.934]),
#  array([ 1.   ,  0.389,  2.   ,  0.611]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.122,  0.   ,  0.878]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.368,  2.   ,  0.632]),
#  array([ 1.   ,  0.129,  3.   ,  0.871]),
#  array([ 2.   ,  0.395,  3.   ,  0.605]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.116,  1.   ,  0.884]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.201,  1.   ,  0.799]),
#  array([ 3.   ,  0.042,  1.   ,  0.958]),
#  array([ 0.   ,  0.253,  1.   ,  0.747]),
#  array([ 0.   ,  0.116,  2.   ,  0.884]),
#  array([ 4.   ,  0.234,  5.   ,  0.766]),
#  array([ 1.   ,  0.215,  3.   ,  0.785]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 3.  ,  0.13,  1.  ,  0.87]),
#  array([ 0.   ,  0.113,  1.   ,  0.887]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.251,  2.   ,  0.749]),
#  array([ 1.   ,  0.343,  2.   ,  0.657]),
#  array([ 2.   ,  0.138,  1.   ,  0.862]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.131,  2.   ,  0.869]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.128,  2.   ,  0.872]),
#  array([ 0.   ,  0.368,  2.   ,  0.632]),
#  array([ 3.   ,  0.385,  1.   ,  0.615]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.383,  1.   ,  0.617]),
#  array([ 3.   ,  0.242,  2.   ,  0.758]),
#  array([ 2.   ,  0.059,  0.   ,  0.941]),
#  array([ 3.  ,  0.11,  1.  ,  0.89]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.368,  1.   ,  0.632]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.353,  3.   ,  0.647]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 1.  ,  0.24,  3.  ,  0.76]),
#  array([ 3.  ,  0.24,  1.  ,  0.76]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 3.  ,  0.26,  1.  ,  0.74]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.,  0.,  0.,  1.]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 2.   ,  0.348,  0.   ,  0.652]),
#  array([ 0.   ,  0.253,  2.   ,  0.747]),
#  array([ 3.   ,  0.114,  0.   ,  0.886]),
#  array([ 3.  ,  0.24,  1.  ,  0.76]),
#  array([ 1.   ,  0.107,  3.   ,  0.893]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.146,  2.   ,  0.854]),
#  array([ 5.   ,  0.168,  4.   ,  0.832]),
#  array([ 5.   ,  0.153,  4.   ,  0.847]),
#  array([ 0.   ,  0.111,  2.   ,  0.889]),
#  array([ 3.   ,  0.079,  1.   ,  0.921]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 4.   ,  0.152,  5.   ,  0.848]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.109,  1.   ,  0.891]),
#  array([ 3.   ,  0.137,  2.   ,  0.863]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.  ,  0.14,  2.  ,  0.86]),
#  array([ 3.   ,  0.259,  1.   ,  0.741]),
#  array([ 2.   ,  0.284,  0.   ,  0.716]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.397,  2.   ,  0.603]),
#  array([ 2.   ,  0.073,  0.   ,  0.927]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.228,  2.   ,  0.772]),
#  array([ 1.   ,  0.242,  3.   ,  0.758]),
#  array([ 0.   ,  0.125,  2.   ,  0.875]),
#  array([ 2.   ,  0.038,  0.   ,  0.962]),
#  array([ 3.   ,  0.133,  2.   ,  0.867]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.   ,  0.136,  2.   ,  0.864]),
#  array([ 1.   ,  0.128,  2.   ,  0.872]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 3.   ,  0.156,  2.   ,  0.844]),
#  array([ 1.   ,  0.362,  3.   ,  0.638]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 1.   ,  0.128,  2.   ,  0.872]),
#  array([ 1.   ,  0.347,  2.   ,  0.653]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.124,  2.   ,  0.876]),
#  array([ 0.   ,  0.081,  1.   ,  0.919]),
#  array([ 3.   ,  0.244,  1.   ,  0.756]),
#  array([ 5.  ,  0.07,  4.  ,  0.93]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.273,  1.   ,  0.727]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.125,  2.   ,  0.875]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 0.   ,  0.348,  2.   ,  0.652]),
#  array([ 3.   ,  0.075,  1.   ,  0.925]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 3.  ,  0.11,  1.  ,  0.89]),
#  array([ 0.   ,  0.131,  2.   ,  0.869]),
#  array([ 0.   ,  0.331,  1.   ,  0.669]),
#  array([ 1.   ,  0.053,  3.   ,  0.947]),
#  array([ 0.   ,  0.258,  2.   ,  0.742]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.   ,  0.123,  0.   ,  0.877]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.117,  1.   ,  0.883]),
#  array([ 1.   ,  0.131,  3.   ,  0.869]),
#  array([ 1.  ,  0.19,  0.  ,  0.81]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 3.   ,  0.052,  1.   ,  0.948]),
#  array([ 3.   ,  0.114,  0.   ,  0.886]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.247,  0.   ,  0.753]),
#  array([ 1.,  0.,  0.,  1.]),
#  array([ 0.   ,  0.125,  2.   ,  0.875]),
#  array([ 3.   ,  0.133,  2.   ,  0.867]),
#  array([ 2.   ,  0.251,  0.   ,  0.749]),
#  array([ 1.,  0.,  0.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 3.   ,  0.124,  1.   ,  0.876]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.066,  2.   ,  0.934]),
#  array([ 3.   ,  0.115,  1.   ,  0.885]),
#  array([ 3.   ,  0.294,  0.   ,  0.706]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 2.   ,  0.479,  1.   ,  0.521]),
#  array([ 2.   ,  0.189,  1.   ,  0.811]),
#  array([ 1.   ,  0.487,  3.   ,  0.513]),
#  array([ 0.  ,  0.37,  2.  ,  0.63]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 2.   ,  0.446,  1.   ,  0.554]),
#  array([ 1.   ,  0.141,  3.   ,  0.859]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.112,  2.   ,  0.888]),
#  array([ 1.   ,  0.079,  0.   ,  0.921]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.115,  1.   ,  0.885]),
#  array([ 0.   ,  0.056,  1.   ,  0.944]),
#  array([ 3.   ,  0.117,  2.   ,  0.883]),
#  array([ 3.   ,  0.133,  1.   ,  0.867]),
#  array([ 3.,  0.,  0.,  1.]),
#  array([ 3.   ,  0.111,  1.   ,  0.889]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.116,  2.   ,  0.884]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.132,  2.   ,  0.868]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 2.   ,  0.489,  1.   ,  0.511]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.304,  2.   ,  0.696]),
#  array([ 0.   ,  0.271,  2.   ,  0.729]),
#  array([ 1.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.132,  2.   ,  0.868]),
#  array([ 3.   ,  0.115,  2.   ,  0.885]),
#  array([ 2.   ,  0.274,  0.   ,  0.726]),
#  array([ 1.   ,  0.062,  3.   ,  0.938]),
#  array([ 0.   ,  0.133,  2.   ,  0.867]),
#  array([ 0.   ,  0.062,  2.   ,  0.938]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 1.   ,  0.401,  3.   ,  0.599]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.238,  1.   ,  0.762]),
#  array([ 1.   ,  0.374,  3.   ,  0.626]),
#  array([ 3.   ,  0.222,  1.   ,  0.778]),
#  array([ 3.   ,  0.305,  2.   ,  0.695]),
#  array([ 3.   ,  0.249,  1.   ,  0.751]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 4.,  0.,  5.,  1.]),
#  array([ 3.   ,  0.047,  1.   ,  0.953]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.109,  2.   ,  0.891]),
#  array([ 4.   ,  0.148,  5.   ,  0.852]),
#  array([ 0.   ,  0.115,  2.   ,  0.885]),
#  array([ 1.,  0.,  0.,  1.]),
#  array([ 4.   ,  0.231,  5.   ,  0.769]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.228,  1.   ,  0.772]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.265,  2.   ,  0.735]),
#  array([ 0.   ,  0.212,  2.   ,  0.788]),
#  array([ 0.   ,  0.374,  2.   ,  0.626]),
#  array([ 1.   ,  0.388,  2.   ,  0.612]),
#  array([ 3.   ,  0.104,  1.   ,  0.896]),
#  array([ 3.   ,  0.152,  1.   ,  0.848]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.406,  0.   ,  0.594]),
#  array([ 0.   ,  0.362,  2.   ,  0.638]),
#  array([ 0.,  0.,  3.,  1.]),
#  array([ 0.   ,  0.278,  1.   ,  0.722]),
#  array([ 3.   ,  0.135,  1.   ,  0.865]),
#  array([ 3.   ,  0.069,  2.   ,  0.931]),
#  array([ 5.   ,  0.154,  4.   ,  0.846]),
#  array([ 5.   ,  0.215,  4.   ,  0.785]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.   ,  0.425,  1.   ,  0.575]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 5.,  0.,  4.,  1.]),
#  array([ 0.   ,  0.237,  2.   ,  0.763]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.412,  1.   ,  0.588]),
#  array([ 2.   ,  0.314,  0.   ,  0.686]),
#  array([ 3.   ,  0.117,  1.   ,  0.883]),
#  array([ 4.   ,  0.104,  5.   ,  0.896]),
#  array([ 2.,  0.,  0.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.082,  2.   ,  0.918]),
#  array([ 1.   ,  0.257,  3.   ,  0.743]),
#  array([ 0.   ,  0.251,  2.   ,  0.749]),
#  array([ 3.   ,  0.119,  1.   ,  0.881]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.394,  1.   ,  0.606]),
#  array([ 4.   ,  0.136,  5.   ,  0.864]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.207,  2.   ,  0.793]),
#  array([ 2.   ,  0.137,  1.   ,  0.863]),
#  array([ 0.   ,  0.103,  2.   ,  0.897]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 1.  ,  0.22,  3.  ,  0.78]),
#  array([ 1.,  0.,  3.,  1.]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.123,  2.   ,  0.877]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.115,  2.   ,  0.885]),
#  array([ 1.   ,  0.119,  2.   ,  0.881]),
#  array([ 3.   ,  0.247,  1.   ,  0.753]),
#  array([ 3.   ,  0.114,  1.   ,  0.886]),
#  array([ 2.   ,  0.078,  3.   ,  0.922]),
#  array([ 3.,  0.,  2.,  1.]),
#  array([ 0.   ,  0.237,  2.   ,  0.763]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 3.   ,  0.104,  0.   ,  0.896]),
#  array([ 0.  ,  0.28,  2.  ,  0.72]),
#  array([ 3.  ,  0.16,  1.  ,  0.84]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 3.   ,  0.078,  1.   ,  0.922]),
#  array([ 0.,  0.,  1.,  1.]),
#  array([ 0.   ,  0.414,  3.   ,  0.586]),
#  array([ 3.   ,  0.097,  1.   ,  0.903]),
#  array([ 3.,  0.,  1.,  1.]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 5.   ,  0.138,  4.   ,  0.862]),
#  array([ 0.  ,  0.11,  2.  ,  0.89]),
#  array([ 3.   ,  0.331,  1.   ,  0.669]),
#  array([ 3.   ,  0.145,  2.   ,  0.855]),
#  array([ 2.   ,  0.111,  0.   ,  0.889]),
#  array([ 0.,  0.,  2.,  1.]),
#  array([ 2.   ,  0.103,  0.   ,  0.897]),
#  array([ 3.   ,  0.103,  1.   ,  0.897]),
#  array([ 0.   ,  0.158,  1.   ,  0.842]),
#  ...]

# %%
tuple(som.attrs)
# Out:
# ('TITLE',
#  'CLASS',
#  'VERSION',
#  'pandas_type',
#  'pandas_version',
#  'encoding',
#  'ndim',
#  'axis0_variety',
#  'axis1_variety',
#  'nblocks',
#  'block0_items_variety')

# %%
som.attrs['axis1_variety']
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-131-521cd371533b> in <module>()
# ----> 1 som.attrs['axis1_variety']
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\aroot\work\h5py\_objects.c:2576)()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\aroot\work\h5py\_objects.c:2535)()
#
# C:\Anaconda3\lib\site-packages\h5py\_hl\attrs.py in __getitem__(self, name)
#      71
#      72         arr = numpy.ndarray(shape, dtype=dtype, order='C')
# ---> 73         attr.read(arr, mtype=htype)
#      74
#      75         if len(arr.shape) == 0:
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\aroot\work\h5py\_objects.c:2576)()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\aroot\work\h5py\_objects.c:2535)()
#
# h5py\h5a.pyx in h5py.h5a.AttrID.read (C:\aroot\work\h5py\h5a.c:5122)()
#
# h5py\_proxy.pyx in h5py._proxy.attr_rw (C:\aroot\work\h5py\_proxy.c:912)()
#
# OSError: Unable to read attribute (No appropriate function for conversion path)

# %%
h5py.enable_ipython_completer()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\h5py\ipy_completer.py in <module>()
#      55     from IPython.utils import generics
# ---> 56     from IPython import TryNext
#      57 except ImportError:
#
# ImportError: cannot import name 'TryNext'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-116-b0519993ebaf> in <module>()
# ----> 1 h5py.enable_ipython_completer()
#
# C:\Anaconda3\lib\site-packages\h5py\__init__.py in enable_ipython_completer()
#      76             pass
#      77         if ip_running:
# ---> 78             from . import ipy_completer
#      79             return ipy_completer.load_ipython_extension()
#      80
#
# C:\Anaconda3\lib\site-packages\h5py\ipy_completer.py in <module>()
#      57 except ImportError:
#      58     # support <ipython-0.11
# ---> 59     from IPython import generics
#      60     from IPython.ipapi import TryNext
#      61
#
# ImportError: cannot import name 'generics'

# %%
som['b
# Out:
# <HDF5 group "/demonstration/0/500" (4 members)>

# %%
afrqs
# Out:
#       minor_allele  minor_frequency  major_allele  major_frequency
# 0              2.0            0.000           1.0            1.000
# 1              3.0            0.129           1.0            0.871
# 2              1.0            0.130           3.0            0.870
# 3              2.0            0.120           0.0            0.880
# 4              0.0            0.049           2.0            0.951
# 5              2.0            0.209           0.0            0.791
# 6              2.0            0.235           0.0            0.765
# 7              1.0            0.000           3.0            1.000
# 8              2.0            0.093           0.0            0.907
# 9              3.0            0.000           1.0            1.000
# 10             3.0            0.400           1.0            0.600
# 11             3.0            0.000           1.0            1.000
# 12             1.0            0.382           3.0            0.618
# 13             0.0            0.100           2.0            0.900
# 14             0.0            0.092           3.0            0.908
# 15             1.0            0.389           3.0            0.611
# 16             3.0            0.116           2.0            0.884
# 17             3.0            0.000           2.0            1.000
# 18             0.0            0.000           2.0            1.000
# 19             4.0            0.000           5.0            1.000
# 20             0.0            0.386           3.0            0.614
# 21             1.0            0.138           2.0            0.862
# 22             3.0            0.000           2.0            1.000
# 23             5.0            0.434           4.0            0.566
# 24             3.0            0.064           1.0            0.936
# 25             0.0            0.251           2.0            0.749
# 26             0.0            0.066           3.0            0.934
# 27             1.0            0.060           0.0            0.940
# 28             1.0            0.000           2.0            1.000
# 29             0.0            0.423           2.0            0.577
# ...            ...              ...           ...              ...
# 1448           0.0            0.259           3.0            0.741
# 1449           3.0            0.375           0.0            0.625
# 1450           2.0            0.196           0.0            0.804
# 1451           3.0            0.000           1.0            1.000
# 1452           5.0            0.000           4.0            1.000
# 1453           3.0            0.000           1.0            1.000
# 1454           1.0            0.126           3.0            0.874
# 1455           2.0            0.481           3.0            0.519
# 1456           2.0            0.122           0.0            0.878
# 1457           0.0            0.054           2.0            0.946
# 1458           0.0            0.483           1.0            0.517
# 1459           5.0            0.000           4.0            1.000
# 1460           0.0            0.114           3.0            0.886
# 1461           1.0            0.069           2.0            0.931
# 1462           3.0            0.128           1.0            0.872
# 1463           3.0            0.246           1.0            0.754
# 1464           1.0            0.000           3.0            1.000
# 1465           0.0            0.122           2.0            0.878
# 1466           3.0            0.000           1.0            1.000
# 1467           0.0            0.000           2.0            1.000
# 1468           0.0            0.281           2.0            0.719
# 1469           2.0            0.000           1.0            1.000
# 1470           0.0            0.258           2.0            0.742
# 1471           3.0            0.000           0.0            1.000
# 1472           0.0            0.138           1.0            0.862
# 1473           1.0            0.071           0.0            0.929
# 1474           2.0            0.243           0.0            0.757
# 1475           0.0            0.260           1.0            0.740
# 1476           0.0            0.126           3.0            0.874
# 1477           1.0            0.000           3.0            1.000
#
# [1478 rows x 4 columns]

# %%
expop = multi_prefounders.population(0)

# %%
sim.stat(expop, alleleFreq=sim.ALL_AVAIL)

# %%
af = analyze.allele_data(expop, alleles, loci)

# %%
af
# Out:
#       minor_allele  minor_frequency  major_allele  major_frequency
# 0              2.0          0.00000           1.0          1.00000
# 1              3.0          0.12850           1.0          0.87150
# 2              1.0          0.11900           3.0          0.88100
# 3              2.0          0.12850           0.0          0.87150
# 4              0.0          0.06125           2.0          0.93875
# 5              2.0          0.24425           0.0          0.75575
# 6              2.0          0.23700           0.0          0.76300
# 7              1.0          0.00000           3.0          1.00000
# 8              2.0          0.11225           0.0          0.88775
# 9              3.0          0.00000           1.0          1.00000
# 10             3.0          0.39125           1.0          0.60875
# 11             3.0          0.00000           1.0          1.00000
# 12             1.0          0.35475           3.0          0.64525
# 13             0.0          0.11550           2.0          0.88450
# 14             0.0          0.10725           3.0          0.89275
# 15             1.0          0.35850           3.0          0.64150
# 16             3.0          0.12375           2.0          0.87625
# 17             3.0          0.00000           2.0          1.00000
# 18             0.0          0.00000           2.0          1.00000
# 19             4.0          0.00000           5.0          1.00000
# 20             0.0          0.37350           3.0          0.62650
# 21             1.0          0.13475           2.0          0.86525
# 22             3.0          0.00000           2.0          1.00000
# 23             5.0          0.42425           4.0          0.57575
# 24             3.0          0.05800           1.0          0.94200
# 25             0.0          0.24725           2.0          0.75275
# 26             0.0          0.06725           3.0          0.93275
# 27             1.0          0.06175           0.0          0.93825
# 28             1.0          0.00000           2.0          1.00000
# 29             0.0          0.39500           2.0          0.60500
# ...            ...              ...           ...              ...
# 1448           0.0          0.27100           3.0          0.72900
# 1449           3.0          0.36700           0.0          0.63300
# 1450           2.0          0.18850           0.0          0.81150
# 1451           3.0          0.00000           1.0          1.00000
# 1452           5.0          0.00000           4.0          1.00000
# 1453           3.0          0.00000           1.0          1.00000
# 1454           1.0          0.12500           3.0          0.87500
# 1455           2.0          0.49650           3.0          0.50350
# 1456           2.0          0.12225           0.0          0.87775
# 1457           0.0          0.05525           2.0          0.94475
# 1458           0.0          0.49450           1.0          0.50550
# 1459           5.0          0.00000           4.0          1.00000
# 1460           0.0          0.11425           3.0          0.88575
# 1461           1.0          0.06650           2.0          0.93350
# 1462           3.0          0.13475           1.0          0.86525
# 1463           3.0          0.24975           1.0          0.75025
# 1464           1.0          0.00000           3.0          1.00000
# 1465           0.0          0.11800           2.0          0.88200
# 1466           3.0          0.00000           1.0          1.00000
# 1467           0.0          0.00000           2.0          1.00000
# 1468           0.0          0.27700           2.0          0.72300
# 1469           2.0          0.00000           1.0          1.00000
# 1470           0.0          0.27025           2.0          0.72975
# 1471           3.0          0.00000           0.0          1.00000
# 1472           0.0          0.14225           1.0          0.85775
# 1473           1.0          0.06900           0.0          0.93100
# 1474           2.0          0.23550           0.0          0.76450
# 1475           0.0          0.26450           1.0          0.73550
# 1476           0.0          0.11775           3.0          0.88225
# 1477           1.0          0.00000           3.0          1.00000
#
# [1478 rows x 4 columns]

# %%
analyze.remap_allele_effect_and_frq_table_loci(aeftable, concordant_segregating_loci)
# Out:
#      locus  alpha_allele  alpha_frequency  alpha_effect  beta_allele  \
# 0        1             1          0.87150      0.000000            3
# 1        2             3          0.88100      0.000000            1
# 2        3             0          0.87150      0.000000            2
# 3        4             2          0.93875      0.000000            0
# 4        5             0          0.75575      0.000000            2
# 5        6             0          0.76300      0.000000            2
# 6        8             0          0.88775      0.000000            2
# 7       10             1          0.60875      0.000000            3
# 8       12             3          0.64525      0.000000            1
# 9       13             2          0.88450      0.000000            0
# 10      14             3          0.89275      0.000000            0
# 11      15             3          0.64150      0.000000            1
# 12      16             2          0.87625      0.000000            3
# 13      20             3          0.62650      0.000000            0
# 14      21             2          0.86525      0.000000            1
# 15      23             5          0.42425      0.000000            4
# 16      24             1          0.94200      0.000000            3
# 17      25             2          0.75275      0.000000            0
# 18      26             3          0.93275      0.000000            0
# 19      27             0          0.93825      0.000000            1
# 20      29             2          0.60500      0.000000            0
# 21      30             2          0.87250      0.000000            0
# 22      31             0          0.75725      0.000000            1
# 23      32             3          0.87600      0.000000            1
# 24      34             1          0.79925      0.000000            3
# 25      36             1          0.63600      0.000000            3
# 26      37             3          0.88225      0.000000            1
# 27      38             5          0.93400      0.000000            4
# 28      39             0          0.94550      0.000000            2
# 29      40             1          0.87425      0.000000            3
# ..     ...           ...              ...           ...          ...
# 913   1433             0          0.86225      0.000000            2
# 914   1434             0          0.74525      0.000000            1
# 915   1438             2          0.75050      0.000000            0
# 916   1439             3          0.86650      0.000000            1
# 917   1440             1          0.63575      0.000000            3
# 918   1442             0          0.60350      0.000000            2
# 919   1444             5          0.69750      0.000000            4
# 920   1445             1          0.17950      0.000000            3
# 921   1446             3          0.74950      0.000000            1
# 922   1447             2          0.74700      0.000000            0
# 923   1448             3          0.72900      0.000000            0
# 924   1449             0          0.63300      0.000000            3
# 925   1450             0          0.81150      0.000000            2
# 926   1454             3          0.87500      0.000000            1
# 927   1455             3          0.50350      0.000000            2
# 928   1456             0          0.87775      0.000000            2
# 929   1457             2          0.94475      0.000000            0
# 930   1458             0          0.49450      0.000000            1
# 931   1460             3          0.88575      0.000000            0
# 932   1461             2          0.93350      0.000000            1
# 933   1462             1          0.86525      0.000000            3
# 934   1463             1          0.75025      0.000000            3
# 935   1465             2          0.88200      0.000000            0
# 936   1468             2          0.72300      1.209494            0
# 937   1470             2          0.72975      0.000000            0
# 938   1472             1          0.85775      0.000000            0
# 939   1473             0          0.93100      0.000000            1
# 940   1474             0          0.76450      0.000000            2
# 941   1475             1          0.73550      0.000000            0
# 942   1476             3          0.88225      0.000000            0
#
#      beta_frequency  beta_effect  difference
# 0           0.12850     0.000000    0.000000
# 1           0.11900     0.000000    0.000000
# 2           0.12850     0.000000    0.000000
# 3           0.06125     0.000000    0.000000
# 4           0.24425     0.000000    0.000000
# 5           0.23700     0.000000    0.000000
# 6           0.11225     0.000000    0.000000
# 7           0.39125     0.000000    0.000000
# 8           0.35475     0.000000    0.000000
# 9           0.11550     0.000000    0.000000
# 10          0.10725     0.000000    0.000000
# 11          0.35850     0.000000    0.000000
# 12          0.12375     0.000000    0.000000
# 13          0.37350     0.000000    0.000000
# 14          0.13475     0.000000    0.000000
# 15          0.57575     0.000000    0.000000
# 16          0.05800     0.000000    0.000000
# 17          0.24725     0.000000    0.000000
# 18          0.06725     0.000000    0.000000
# 19          0.06175     0.000000    0.000000
# 20          0.39500     0.000000    0.000000
# 21          0.12750     0.000000    0.000000
# 22          0.24275     0.000000    0.000000
# 23          0.12400     0.000000    0.000000
# 24          0.20075     0.000000    0.000000
# 25          0.36400     0.000000    0.000000
# 26          0.11775     0.000000    0.000000
# 27          0.06600     0.000000    0.000000
# 28          0.05450     0.000000    0.000000
# 29          0.12575     0.000000    0.000000
# ..              ...          ...         ...
# 913         0.13775     0.000000    0.000000
# 914         0.25475     0.000000    0.000000
# 915         0.24950     0.000000    0.000000
# 916         0.13350     0.000000    0.000000
# 917         0.36425     0.000000    0.000000
# 918         0.39650     0.000000    0.000000
# 919         0.30250     0.000000    0.000000
# 920         0.82050     0.000000    0.000000
# 921         0.25050     0.000000    0.000000
# 922         0.25300     0.000000    0.000000
# 923         0.27100     0.000000    0.000000
# 924         0.36700     0.000000    0.000000
# 925         0.18850     0.000000    0.000000
# 926         0.12500     0.000000    0.000000
# 927         0.49650     0.000000    0.000000
# 928         0.12225     0.000000    0.000000
# 929         0.05525     0.000000    0.000000
# 930         0.50550     0.000000    0.000000
# 931         0.11425     0.000000    0.000000
# 932         0.06650     0.000000    0.000000
# 933         0.13475     0.000000    0.000000
# 934         0.24975     0.000000    0.000000
# 935         0.11800     0.000000    0.000000
# 936         0.27700     0.769592    0.439902
# 937         0.27025     0.000000    0.000000
# 938         0.14225     0.000000    0.000000
# 939         0.06900     0.000000    0.000000
# 940         0.23550     0.000000    0.000000
# 941         0.26450     0.000000    0.000000
# 942         0.11775     0.000000    0.000000
#
# [943 rows x 8 columns]

# %%
analyze.remap_afrq_table_loci(af, concordant_segregating_loci)
# Out:
#      minor_allele  minor_frequency  major_allele  major_frequency
# 0             3.0          0.12850           1.0          0.87150
# 1             1.0          0.11900           3.0          0.88100
# 2             2.0          0.12850           0.0          0.87150
# 3             0.0          0.06125           2.0          0.93875
# 4             2.0          0.24425           0.0          0.75575
# 5             2.0          0.23700           0.0          0.76300
# 6             2.0          0.11225           0.0          0.88775
# 7             3.0          0.39125           1.0          0.60875
# 8             1.0          0.35475           3.0          0.64525
# 9             0.0          0.11550           2.0          0.88450
# 10            0.0          0.10725           3.0          0.89275
# 11            1.0          0.35850           3.0          0.64150
# 12            3.0          0.12375           2.0          0.87625
# 13            0.0          0.37350           3.0          0.62650
# 14            1.0          0.13475           2.0          0.86525
# 15            5.0          0.42425           4.0          0.57575
# 16            3.0          0.05800           1.0          0.94200
# 17            0.0          0.24725           2.0          0.75275
# 18            0.0          0.06725           3.0          0.93275
# 19            1.0          0.06175           0.0          0.93825
# 20            0.0          0.39500           2.0          0.60500
# 21            0.0          0.12750           2.0          0.87250
# 22            1.0          0.24275           0.0          0.75725
# 23            1.0          0.12400           3.0          0.87600
# 24            3.0          0.20075           1.0          0.79925
# 25            3.0          0.36400           1.0          0.63600
# 26            1.0          0.11775           3.0          0.88225
# 27            4.0          0.06600           5.0          0.93400
# 28            2.0          0.05450           0.0          0.94550
# 29            3.0          0.12575           1.0          0.87425
# ..            ...              ...           ...              ...
# 913           2.0          0.13775           0.0          0.86225
# 914           1.0          0.25475           0.0          0.74525
# 915           0.0          0.24950           2.0          0.75050
# 916           1.0          0.13350           3.0          0.86650
# 917           3.0          0.36425           1.0          0.63575
# 918           2.0          0.39650           0.0          0.60350
# 919           4.0          0.30250           5.0          0.69750
# 920           1.0          0.17950           3.0          0.82050
# 921           1.0          0.25050           3.0          0.74950
# 922           0.0          0.25300           2.0          0.74700
# 923           0.0          0.27100           3.0          0.72900
# 924           3.0          0.36700           0.0          0.63300
# 925           2.0          0.18850           0.0          0.81150
# 926           1.0          0.12500           3.0          0.87500
# 927           2.0          0.49650           3.0          0.50350
# 928           2.0          0.12225           0.0          0.87775
# 929           0.0          0.05525           2.0          0.94475
# 930           0.0          0.49450           1.0          0.50550
# 931           0.0          0.11425           3.0          0.88575
# 932           1.0          0.06650           2.0          0.93350
# 933           3.0          0.13475           1.0          0.86525
# 934           3.0          0.24975           1.0          0.75025
# 935           0.0          0.11800           2.0          0.88200
# 936           0.0          0.27700           2.0          0.72300
# 937           0.0          0.27025           2.0          0.72975
# 938           0.0          0.14225           1.0          0.85775
# 939           1.0          0.06900           0.0          0.93100
# 940           2.0          0.23550           0.0          0.76450
# 941           0.0          0.26450           1.0          0.73550
# 942           0.0          0.11775           3.0          0.88225
#
# [943 rows x 4 columns]

# %%
aeftable = analyze.generate_allele_effects_frequencies(expop, alleles, qtl, allele_effects)

# %%
aefs = pd.HDFStore('demonstration_allele_.h5')

# %%
loci = list(range(1478))
droppable_loci = [droppable_locus for droppable_locus in loci if droppable_locus not in concordant_segregating_loci]

# %%
for sample in sample_sizes:
    for rep in range(number_of_replicates):
        allele_frequencies_table = allele_frequencies['/'+'/'.join(['demonstration', str(rep), str(sample)])]
        subset_afrqs_table = analyze.remap_afrq_table_loci(allele_frequencies_table, saegus_to_tassel_loci)
        gwas_results_file_name = 'demonstration_'+str(rep)+'_'+str(sample)+'_out_2.txt'
        qvalues_file_name = 'demonstration_'+str(rep)+'_'+str(sample)+'_qvalues.txt'
        super_table = analyze.generate_super_table(gwas_results_file_name, 
                                                  qvalues_file_name, 
                                                  subset_afrqs_table,
                                                  expanded)
        super_table.to_csv('demonstration_'+str(rep)+'_'+str(sample)+'_super_table.txt', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-3a1cc4dd98af> in <module>()
#       8                                                   qvalues_file_name,
#       9                                                   subset_afrqs_table,
# ---> 10                                                   expanded)
#      11         super_table.to_csv('demonstration_'+str(rep)+'_'+str(sample)+'_super_table.txt', sep='\t')
#
# NameError: name 'expanded' is not defined

# %%
super_table

# %%
remapped_afrqs = analyze.remap_afrq_table_loci(allele_frequencies_table, saegus_to_tassel_loci)

# %%
sutable = analyze.generate_super_table('demonstration_0_1000_out_2.txt', 'demonstration_0_1000_qvalues.txt', remapped_afrqs, expanded)

# %%
sutable

# %%
analyze.write_multiple_sample_analyzer(sample_library, sample_sizes, qtl, alleles, 
                                       allele_effects, 0.7,  concordant_segregating_loci, 
                                       run_id='demonstration', 
                                       allele_frequency_hdf='demonstration_storage.h5')

# %%
expanded

# %%
demonstration = analyze.Study(run_id)

# %%
power_fpr_raw_data = demonstration.collect_power_analysis_data(sample_sizes, number_of_replicates, expanded)

# %%
raw_demonstration_data = shelve.open('demonstration_raw_data')
for size, data_list in power_fpr_raw_data.items():
    raw_demonstration_data[str(size)] = data_list
raw_demonstration_data.close()

# %%
power_fpr_raw_data

# %%
power_fpr_raw_data[500][0].index

# %%
subsuper_table = power_fpr_raw_data[500][0].join(subset)

# %%
power_fpr_raw_data

# %%
subsuper_table

# %%
results, true_positives, false_positives = demonstration.calculate_power_fpr(power_fpr_raw_data, sample_sizes, 
                                                                             number_of_replicates, number_of_qtl)

# %%
qtl

# %%
results

# %%
true_positives

# %%
results

# %%
true_positives

# %%
results.to_csv(run_id + '_fpr_results.txt', sep='\t')

# %%
detection_table = demonstration.probability_of_detection(allele_effects_table, sample_sizes, 
                                                         number_of_replicates, true_positives)

# %%
detection_table

# %%
detection_table.to_csv(run_id + '_probability_of_detection.txt', sep='\t')

# %%
mean_stdev = pd.DataFrame([results.mean(), results.std()], index=['mean', 'standard_dev']).T

# %%
mean_stdev.to_csv('beneath_these_waves_power_mean_stdev')

# %%
prob_detection_table['difference'].corr(prob_detection_table['detected'])

# %%
results.to_csv('beneath_these_waves_power_fpr_results.txt', sep='\t', index=False)

# %% [markdown]
# ### Running Family Comparison

# %% [markdown]
# #### Modified Existing Phenotype Trait Vector
#     Reads existing phenotype file and writes the modified
#     values under a new file-name

# %%
def modify_existing_phenotypes(existing_phenotype_file, modded_values, modified_phenotype_file):
    existing_phenotypes = np.array(pd.read_csv(existing_phenotype_file, sep='\t'))
    modified_phenotypes = np.array(existing_phenotypes)
    modified_phenotypes[:, 1] = modded_values
    modified_pheno_output = pd.DataFrame(modified_phenotypes)
    header = "<Trait>\tsim\n"    
    with open(modified_phenotype_file, 'w') as mod_pheno_file:
        mod_pheno_file.write(header)
        modified_pheno_output.to_csv(mod_pheno_file, sep='\t', index=False, header=False)

# %%
modify_existing_phenotypes("heaven_denies_0_750_phenotype_vector.txt",
                          np.ones((750)),
                          "blood_hands_0_750_phenotype_vector.txt")

# %% [markdown]
# ## Newly Developed Functions

# %% [markdown]
# ### Collects Samples from Each Replicate
#     Stores them in a library of lists

# %%
def collect_samples(replicate_populations, sample_sizes, run_id):
    """
    Testing for concordance of segregating loci among samples requires that
    the samples be gathered in advance. Collects samples from replicate_populations

    :param replicate_populations: Multi-replicate population to analyze
    :param sample_sizes: Size of sample to gather.

    :note: :py:func:`len(sample_sizez)` == number of samples gathered from each replicate.

    :param str run_id: Identifier
    :return: List of populations
    """
    samples = {}
    for rep in replicate_populations.populations():
        samples[rep.dvars().rep] = [sim.sampling.drawRandomSample(rep, sizes=sample_size) for sample_size in sample_sizes]
    return samples

# %% [markdown]
# ### Calculates Allele Frequencies for Each Sample
#     Stores in a single HDF File

# %%
def multi_sample_allele_frq_storage(library_of_samples, alleles, run_id='heaven_denies'):

    hdf_store = pd.HDFStore(run_id + '_afrqs.h5')

    for rep_id, samples in library_of_samples.items():
        for sample in samples:
            af = analyze.allele_data(sample, alleles,
                                 range(sample.totNumLoci()))

            name = run_id + '/' + str(rep_id) + '/' + str(sample.popSize())

            hdf_store.put(name, af)
    hdf_store.close()

# %% [markdown]
# # Visualization

# %%
from bokeh.io import output_notebook()
from bokeh.charts import Dot, show, output_file

output_notebook()

data_2 = {
    'power': [0.2, 0.4, 0.6, 0.8]
    'sample_sizes': ['250', '500', '750', '1000'],
    'rep' = ['0', '0', '0', '0']
}

# x-axis labels pulled from the interpreter column, stacking labels from sample column
#dots = Dot(data, values='timing', label='interpreter',
#           group='sample', agg='mean',
#           title="Python Interpreter Sampling",
#           legend='top_right', width=600)
           
dots_2 = Dot(data_2, values='power', label='sample_sizes',
                group='rep', agg='mean', 
                title="First Bokeh Dot PLot",
                legend='top_right', width=600)


output_file("dots_example.html", title="dots.py example")

show(dots)
