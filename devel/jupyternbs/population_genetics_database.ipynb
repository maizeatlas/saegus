# %%
import simuPOP as sim
from pymongo import MongoClient
# Out:
# simuPOP Version 1.1.6 : Copyright (c) 2004-2011 Bo Peng
# Revision 4972 (May  1 2015) for Python 3.4.3 (64bit, 1thread)
# Random Number Generator is set to mt19937 with random seed 0x317626a2.
# This is the standard short allele version with 256 maximum allelic states.
# For more information, please visit http://simupop.sourceforge.net,
# or email simupop-list@lists.sourceforge.net (subscription required).

# %%
pop = sim.loadPopulation('prefounders.pop')

# %%
ind = pop.individual(1)

# %%
genotype = {
    "0": list(ind.genotype(ploidy=0)),
    "1": list(ind.genotype(ploidy=1))
}

# %%
genotype
# Out:
# {0: [1,
#   1,
#   1,
#   0,
#   2,
#   0,
#   0,
#   3,
#   0,
#   1,
#   3,
#   1,
#   1,
#   2,
#   3,
#   1,
#   2,
#   2,
#   2,
#   5,
#   0,
#   2,
#   2,
#   4,
#   1,
#   2,
#   0,
#   0,
#   2,
#   0,
#   2,
#   0,
#   3,
#   0,
#   1,
#   2,
#   1,
#   3,
#   4,
#   0,
#   3,
#   2,
#   2,
#   3,
#   0,
#   2,
#   3,
#   3,
#   2,
#   2,
#   1,
#   3,
#   1,
#   0,
#   0,
#   2,
#   1,
#   1,
#   1,
#   1,
#   1,
#   2,
#   0,
#   2,
#   0,
#   2,
#   2,
#   2,
#   0,
#   1,
#   5,
#   2,
#   1,
#   4,
#   2,
#   1,
#   0,
#   3,
#   4,
#   2,
#   3,
#   2,
#   2,
#   3,
#   3,
#   3,
#   3,
#   2,
#   1,
#   2,
#   4,
#   1,
#   0,
#   0,
#   3,
#   2,
#   1,
#   1,
#   2,
#   0,
#   1,
#   2,
#   2,
#   0,
#   1,
#   0,
#   2,
#   1,
#   2,
#   2,
#   3,
#   3,
#   0,
#   1,
#   1,
#   4,
#   3,
#   1,
#   4,
#   1,
#   3,
#   2,
#   0,
#   2,
#   1,
#   3,
#   1,
#   1,
#   1,
#   0,
#   2,
#   1,
#   1,
#   1,
#   1,
#   5,
#   1,
#   3,
#   3,
#   1,
#   2,
#   2,
# ...

# %%
client = MongoClient()

# %%
ind.infoFields()
# Out:
# ('ind_id', 'father_id', 'mother_id', 'fitness', 'p', 'g')

# %%
db = client['population_database']

# %%
collection = db['individual_collection']

# %%
data = {"ind_id": ind.ind_id,
       "genotype": genotype,
       }

# %%
inds = db.individuals

# %%
inds_id = inds.insert_one(data).inserted_id

# %%
inds_id
# Out:
# ObjectId('569813f0c3dd920100e7864c')

# %%
integer_to_snp = {
    "0": "A",
    "1": "C",
    "2": "G",
    "3": "T",
    "4": "D",
    "5": "I",
}

# %%
inds.insert_one(integer_to_snp)

# %%
decoder = inds.insert_one(integer_to_snp).inserted_id
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-27-33240ebf5d5d> in <module>()
# ----> 1 decoder = inds.insert_one(integer_to_snp).inserted_id
#
# C:\Anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation)
#     623             return InsertOneResult(
#     624                 self._insert(sock_info, document,
# --> 625                              bypass_doc_val=bypass_document_validation),
#     626                 self.write_concern.acknowledged)
#     627
#
# C:\Anaconda3\lib\site-packages\pymongo\collection.py in _insert(self, sock_info, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     528             return self._insert_one(
#     529                 sock_info, docs, ordered,
# --> 530                 check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     531
# ...

# %%
db.collection_names(include_system_collections=False)
# Out:
# ['individuals']

# %%
population = []
for member in pop.individuals():
  population.append(
        {"ind": {
            "0": str(list(member.genotype(ploidy=0))),
            "1": str(list(member.genotype(ploidy=1)))
        },
    })

# %%
population[0][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-f8bab418e7ce> in <module>()
# ----> 1 population[0][0]
#
# KeyError: 0

# %%
type(population)
# Out:
# list

# %%
population.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-4fc8e9c9351d> in <module>()
# ----> 1 population.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
type(population)
# Out:
# list

# %%
result = inds.insert_many(population)

# %%
result.inserted_ids
# Out:
# [ObjectId('56981864c3dd920100e7864e'),
#  ObjectId('56981864c3dd920100e7864f'),
#  ObjectId('56981864c3dd920100e78650'),
#  ObjectId('56981864c3dd920100e78651'),
#  ObjectId('56981864c3dd920100e78652'),
#  ObjectId('56981864c3dd920100e78653'),
#  ObjectId('56981864c3dd920100e78654'),
#  ObjectId('56981864c3dd920100e78655'),
#  ObjectId('56981864c3dd920100e78656'),
#  ObjectId('56981864c3dd920100e78657'),
#  ObjectId('56981864c3dd920100e78658'),
#  ObjectId('56981864c3dd920100e78659'),
#  ObjectId('56981864c3dd920100e7865a'),
#  ObjectId('56981864c3dd920100e7865b'),
#  ObjectId('56981864c3dd920100e7865c'),
#  ObjectId('56981864c3dd920100e7865d'),
#  ObjectId('56981864c3dd920100e7865e'),
#  ObjectId('56981864c3dd920100e7865f'),
#  ObjectId('56981864c3dd920100e78660'),
#  ObjectId('56981864c3dd920100e78661'),
#  ObjectId('56981864c3dd920100e78662'),
#  ObjectId('56981864c3dd920100e78663'),
#  ObjectId('56981864c3dd920100e78664'),
#  ObjectId('56981864c3dd920100e78665'),
# ...
